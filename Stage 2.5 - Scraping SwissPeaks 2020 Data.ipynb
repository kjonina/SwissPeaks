# %% [markdown]
# # SwissPeaks Data
#
# In this code, Swiss Peaks website is scraped. The raw data is then saved to a folder with race and year. No cleaning is done.

# %%
import requests
import json
import html
import pandas as pd
import time
import re
import unicodedata
import datetime
import random
import numpy as np
from datetime import timedelta

# Start the timer
start_time = time.time()

year = '2020'
male_url = 'https://my1.raceresult.com/156560/RRPublish/data/list?key=2049a5fb34f5e180b9d6cf54d6150d67&listname=Online%7CFinal&page=results&contest=0&r=group&name=%231_Swiss%20Peaks%20360%0C%232_Male&f=Swiss%20Peaks%20360%0C%0C%3CIgnore%3E'
female_url = 'https://my1.raceresult.com/156560/RRPublish/data/list?key=2049a5fb34f5e180b9d6cf54d6150d67&listname=Online%7CFinal&page=results&contest=0&r=group&name=%231_Swiss%20Peaks%20360%0C%231_Female&f=Swiss%20Peaks%20360%0C%0C%3CIgnore%3E'
delay_seconds = 3

# %% [markdown]
# ## Scraping Swiss Peaks 2020 Data from the website

# %%
def reformat_name(name_str):
    parts = [p.strip() for p in name_str.split(',')]
    return f"{parts[1]} {parts[0]}" if len(parts) == 2 else name_str


runner_list = []

for url in [male_url, female_url]:
    print(f"Fetching from: {url}")
    
    # Send GET request
    response = requests.get(url)

    if response.status_code == 200:
        json_data = response.json()
        
        # Extract the specific race data
        race_participants = json_data['data']
    #     print(race_participants)
        extracted_list = []

        for participant in race_participants:
            
            try:
                bib =  participant[0]
                bib_2 =  participant[1]
                rank =  participant[2]                
            
                # Format name
                formatted_name = reformat_name(participant[3])
                formatted_name = formatted_name.title()

                
                match = re.search(r'\[img:flags/([A-Z]{2})\.gif\]', participant[4])
                country_code = match.group(1) if match else ""

                birth_year =  participant[5] 
                
                if '_Male&' in url:
                    gender = 'M'
                elif 'Female' in url:
                    gender = 'F'

                club =  participant[6]  

                # Convert time
                chip_time = participant[7]
                formatted_chip_time = pd.to_timedelta(chip_time)
                
                runner_info = [bib, bib_2, rank,
                               formatted_name, country_code,
                               birth_year, gender,
                               club, formatted_chip_time]
                print(runner_info, '\n', '*'*20)
                runner_list.append(runner_info)
            except:
                print('Issue',participant)


    else:
        print(f"Failed to retrieve data. Status code: {response.status_code}")

    time.sleep(delay_seconds)
    print('******* delay! ******* ')
# Out:
# Fetching from: https://my1.raceresult.com/156560/RRPublish/data/list?key=2049a5fb34f5e180b9d6cf54d6150d67&listname=Online%7CFinal&page=results&contest=0&r=group&name=%231_Swiss%20Peaks%20360%0C%232_Male&f=Swiss%20Peaks%20360%0C%0C%3CIgnore%3E
# ['2', '2', '1.', 'Franco Collé', 'IT', '1978', 'M', 'HOKA ONE ONE/ Karpos', Timedelta('2 days 14:45:34')]
#  ********************
# ['8', '8', '2.', 'Jonas Russi', 'CH', '1985', 'M', '', Timedelta('2 days 14:45:35')]
#  ********************
# ['1', '1', '3.', 'Andrea Mattiato', 'IT', '1978', 'M', '', Timedelta('2 days 22:32:18')]
#  ********************
# ['3', '3', '4.', 'Michael Nançoz', 'CH', '1988', 'M', '', Timedelta('3 days 05:08:16')]
#  ********************
# ['250', '250', '5.', 'Javier Galve Sainz De Varanda', 'ES', '1982', 'M', '', Timedelta('3 days 08:19:35')]
#  ********************
# ['13', '13', '6.', 'Rainer Hilz', 'DE', '1985', 'M', '', Timedelta('3 days 08:53:25')]
#  ********************
# ['93', '93', '7.', 'Matthieu Moreau', 'FR', '1980', 'M', '', Timedelta('3 days 10:57:54')]
#  ********************
# ['5', '5', '8.', 'Jérôme Lucas', 'FR', '1973', 'M', '', Timedelta('3 days 11:17:54')]
#  ********************
# ['41', '41', '8.', 'Jean-Marc Laving', 'FR', '1979', 'M', '', Timedelta('3 days 11:17:45')]
#  ********************
# ['7', '7', '10.', 'Francesc Martin Toro', 'ES', '1983', 'M', '', Timedelta('3 days 14:30:03')]
#  ********************
# ['30', '30', '11.', 'Pirin Galov', 'BG', '1974', 'M', '', Timedelta('3 days 15:25:32')]
#  ********************
# ['25', '25', '12.', 'Mathieu Plamondon', 'CA', '1980', 'M', '', Timedelta('3 days 16:54:21')]
#  ********************
# ['52', '52', '13.', 'Philippe Debadier', 'FR', '1978', 'M', '', Timedelta('3 days 16:53:59')]
#  ********************
# ['42', '42', '14.', 'Tim Woodier', 'GB', '1981', 'M', '', Timedelta('3 days 17:52:44')]
#  ********************
# ['63', '63', '15.', 'Jonas Biland', 'CH', '1988', 'M', '', Timedelta('3 days 18:23:23')]
#  ********************
# ['20', '20', '16.', 'Marcel Schriber', 'CH', '1976', 'M', '', Timedelta('3 days 18:51:24')]
#  ********************
# ['54', '54', '17.', 'Benoît Clément', 'CH', '1967', 'M', '', Timedelta('3 days 19:19:09')]
#  ********************
# ['35', '35', '18.', 'Nicolas Lasparets', 'FR', '1980', 'M', '', Timedelta('3 days 19:26:32')]
#  ********************
# ['49', '49', '19.', 'Sylvain Oeillet', 'FR', '1975', 'M', '', Timedelta('3 days 20:17:40')]
#  ********************
# ['34', '34', '20.', 'Kurt Nadler', 'CH', '1967', 'M', 'Team Compressport', Timedelta('3 days 20:57:40')]
#  ********************
# ['40', '40', '21.', 'Thomas Quirk', 'US', '1975', 'M', '', Timedelta('3 days 22:10:44')]
#  ********************
# ['277', '1648', '22.', 'Andréa Braga', 'BE', '1988', 'M', 'Double Peaks', Timedelta('3 days 22:21:32')]
#  ********************
# ['19', '19', '23.', 'Michael Burkhalter', 'CH', '1987', 'M', '', Timedelta('3 days 22:33:34')]
#  ********************
# ['88', '88', '24.', 'Manuel Brügger', 'CH', '1980', 'M', '', Timedelta('3 days 22:52:46')]
#  ********************
# ['76', '76', '25.', 'Roland Pugin', 'CH', '1965', 'M', '', Timedelta('3 days 23:52:32')]
#  ********************
# ['157', '157', '26.', 'Bastien Deliau', 'FR', '1974', 'M', '', Timedelta('3 days 23:58:23')]
#  ********************
# ['80', '80', '27.', 'Maarten Altena', 'NL', '1983', 'M', '', Timedelta('4 days 01:01:22')]
#  ********************
# ['271', '1360', '28.', 'Brice Jacquot', 'FR', '1980', 'M', 'HOKA ONE ONE', Timedelta('4 days 01:52:33')]
#  ********************
# ['31', '31', '29.', 'Paul Moog', 'FR', '1969', 'M', '', Timedelta('4 days 02:43:43')]
#  ********************
# ['81', '81', '30.', 'Roger Gilgen', 'CH', '1968', 'M', '', Timedelta('4 days 02:43:51')]
#  ********************
# ['9', '9', '31.', 'Andi Mamić', 'SI', '1977', 'M', '', Timedelta('4 days 03:11:01')]
#  ********************
# ['95', '95', '32.', 'Anthony Samain', 'BE', '1969', 'M', '', Timedelta('4 days 04:28:37')]
#  ********************
# ['111', '111', '33.', 'Nicholas Turin', 'CH', '1972', 'M', '', Timedelta('4 days 04:34:06')]
#  ********************
# ['27', '27', '34.', 'Laurent Grucker', 'FR', '1973', 'M', '', Timedelta('4 days 04:42:04')]
#  ********************
# ['58', '58', '35.', 'Christoph Castelberg', 'CH', '1968', 'M', '', Timedelta('4 days 05:28:52')]
#  ********************
# ['75', '75', '36.', 'Pierre Dechnik', 'FR', '1974', 'M', '', Timedelta('4 days 06:32:34')]
#  ********************
# ['69', '69', '37.', 'Hervé Fuchs', 'FR', '1970', 'M', '', Timedelta('4 days 06:33:04')]
#  ********************
# ['83', '83', '38.', 'Eric Moine', 'FR', '1960', 'M', '', Timedelta('4 days 06:33:12')]
#  ********************
# ['74', '74', '39.', 'Olivier Bourdais', 'FR', '1971', 'M', '', Timedelta('4 days 07:03:23')]
#  ********************
# ['29', '29', '40.', 'Gilles Samuel', 'CH', '1978', 'M', '', Timedelta('4 days 07:21:33')]
#  ********************
# ['17', '17', '41.', 'Julien Délèze', 'CH', '1983', 'M', '', Timedelta('4 days 07:47:36')]
#  ********************
# ['47', '47', '42.', 'Dario Pedrotti', 'IT', '1974', 'M', '', Timedelta('4 days 08:10:57')]
#  ********************
# ['161', '161', '43.', 'Patrick Lauraux', 'CH', '1971', 'M', '', Timedelta('4 days 08:27:52')]
#  ********************
# ['28', '28', '44.', 'Matthias Klaus', 'AT', '1991', 'M', '', Timedelta('4 days 08:43:28')]
#  ********************
# ['94', '94', '45.', 'Cesare Mauri', 'IT', '1975', 'M', '', Timedelta('4 days 09:13:23')]
#  ********************
# ['97', '97', '46.', 'Vincent Hunout', 'FR', '1979', 'M', '', Timedelta('4 days 09:15:36')]
#  ********************
# ['79', '79', '47.', 'Laurent Lambert', 'FR', '1970', 'M', '', Timedelta('4 days 09:33:56')]
#  ********************
# ['230', '230', '48.', 'Alexander Khalyapin', 'RU', '1968', 'M', '', Timedelta('4 days 09:40:56')]
#  ********************
# ['270', '454', '49.', 'Laurent Thierry', 'CH', '1972', 'M', '', Timedelta('4 days 09:54:39')]
#  ********************
# ['84', '84', '50.', 'Roman Bürgler', 'CH', '1973', 'M', '', Timedelta('4 days 10:12:29')]
#  ********************
# ['36', '36', '51.', 'Francois Dunand', 'FR', '1976', 'M', '', Timedelta('4 days 10:29:27')]
#  ********************
# ['46', '46', '52.', 'Sébastien Giraud', 'FR', '1982', 'M', '', Timedelta('4 days 10:34:30')]
#  ********************
# ['133', '133', '53.', 'Thomas Rindlisbacher', 'CH', '1973', 'M', '', Timedelta('4 days 10:47:03')]
#  ********************
# ['118', '118', '54.', 'Cedric Touny', 'FR', '1989', 'M', '', Timedelta('4 days 10:57:00')]
#  ********************
# ['105', '105', '55.', 'Loïc Fontanel', 'FR', '1988', 'M', '', Timedelta('4 days 11:14:21')]
#  ********************
# ['251', '251', '56.', 'Peter Hjelmstrom', 'SE', '1973', 'M', '', Timedelta('4 days 11:26:08')]
#  ********************
# ['269', '269', '57.', 'Alban Veneugues', 'FR', '1979', 'M', '', Timedelta('4 days 11:40:07')]
#  ********************
# ['211', '211', '58.', 'Arnaud Simard', 'FR', '1973', 'M', '', Timedelta('4 days 11:41:12')]
#  ********************
# ['55', '55', '59.', 'Theodore Delaval', 'FR', '1975', 'M', '', Timedelta('4 days 11:48:46')]
#  ********************
# ['37', '37', '60.', 'Olivier Jouffrey', 'FR', '1970', 'M', '', Timedelta('4 days 11:58:26')]
#  ********************
# ['171', '171', '61.', 'Philippe Ciapa', 'FR', '1963', 'M', '', Timedelta('4 days 11:59:14')]
#  ********************
# ['113', '113', '62.', 'Daniel Grüterich', 'DE', '1981', 'M', '', Timedelta('4 days 12:21:16')]
#  ********************
# ['114', '114', '63.', 'Poskin Julien', 'BE', '1982', 'M', '', Timedelta('4 days 12:21:36')]
#  ********************
# ['127', '127', '64.', 'Gilbert Villien', 'FR', '1961', 'M', '', Timedelta('4 days 12:28:54')]
#  ********************
# ['273', '1382', '65.', 'Claude Vidal', 'FR', '1968', 'M', '', Timedelta('4 days 12:41:35')]
#  ********************
# ['32', '32', '66.', 'Tomasz Sadowski', 'PL', '1977', 'M', '', Timedelta('4 days 13:05:59')]
#  ********************
# ['119', '119', '67.', 'Ivan Hunziker', 'CH', '1983', 'M', '', Timedelta('4 days 13:20:38')]
#  ********************
# ['151', '151', '68.', 'Frédéric Duboux', 'CH', '1969', 'M', '', Timedelta('4 days 13:53:32')]
#  ********************
# ['156', '156', '69.', 'Benjamin Schmid', 'CH', '1978', 'M', '', Timedelta('4 days 14:02:04')]
#  ********************
# ['272', '1644', '70.', 'Yannick Arbel', 'FR', '1976', 'M', '', Timedelta('4 days 14:42:18')]
#  ********************
# ['92', '92', '71.', 'Nicolas Miniggio', 'FR', '1980', 'M', '', Timedelta('4 days 14:55:46')]
#  ********************
# ['192', '192', '72.', 'Julien Didier', 'FR', '1981', 'M', '', Timedelta('4 days 14:59:55')]
#  ********************
# ['153', '153', '73.', 'Vittorio Benvenuti', 'IT', '1964', 'M', '', Timedelta('4 days 15:21:16')]
#  ********************
# ['104', '104', '74.', 'Pierfrancesco Turra', 'IT', '1967', 'M', '', Timedelta('4 days 15:21:13')]
#  ********************
# ['120', '120', '75.', 'Paul Bremmers', 'NL', '1973', 'M', '', Timedelta('4 days 16:12:50')]
#  ********************
# ['229', '229', '76.', 'Xavier Hugon', 'FR', '1983', 'M', '', Timedelta('4 days 16:18:41')]
#  ********************
# ['21', '21', '77.', 'Michael Jeppesen', 'DK', '1988', 'M', '', Timedelta('4 days 16:35:51')]
#  ********************
# ['190', '190', '78.', 'Stephane Alleguede', 'FR', '1972', 'M', '', Timedelta('4 days 16:48:20')]
#  ********************
# ['71', '71', '79.', 'Erwin Bauer', 'DE', '1972', 'M', '', Timedelta('4 days 16:56:38')]
#  ********************
# ['134', '134', '80.', 'Joachim Bühler', 'CH', '1972', 'M', '', Timedelta('4 days 17:11:45')]
#  ********************
# ['124', '124', '81.', 'Timothy Stirling', 'GB', '1983', 'M', '', Timedelta('4 days 17:38:20')]
#  ********************
# ['154', '154', '82.', 'Julien Thiémard', 'CH', '1982', 'M', '', Timedelta('4 days 17:47:46')]
#  ********************
# ['125', '125', '83.', 'Marek Szramowiat', 'PL', '1977', 'M', '', Timedelta('4 days 17:49:42')]
#  ********************
# ['102', '102', '84.', 'Daniel Milewicz', 'PL', '1984', 'M', '', Timedelta('4 days 17:49:49')]
#  ********************
# ['116', '116', '85.', 'William Chevy', 'FR', '1986', 'M', '', Timedelta('4 days 18:10:46')]
#  ********************
# ['126', '126', '86.', 'Sébastien Herrmann', 'FR', '1973', 'M', '', Timedelta('4 days 18:11:24')]
#  ********************
# ['115', '115', '87.', 'Christian Landresse', 'LU', '1969', 'M', '', Timedelta('4 days 18:33:05')]
#  ********************
# ['158', '158', '88.', 'Laurent Domont', 'FR', '1965', 'M', '', Timedelta('4 days 19:01:50')]
#  ********************
# ['176', '176', '89.', 'Markus Werz', 'CH', '1972', 'M', '', Timedelta('4 days 19:19:06')]
#  ********************
# ['179', '179', '90.', 'Sérgio Moreira', 'PT', '1977', 'M', '', Timedelta('4 days 19:30:47')]
#  ********************
# ['215', '215', '91.', 'Diego Léon', 'PY', '1987', 'M', '', Timedelta('4 days 20:20:23')]
#  ********************
# ['181', '181', '92.', 'Christophe Traina', 'BE', '1972', 'M', '', Timedelta('4 days 20:34:23')]
#  ********************
# ['140', '140', '93.', 'Nicolas Vanhaecke', 'FR', '1975', 'M', 'BCVS Mount Asics Team', Timedelta('4 days 21:31:05')]
#  ********************
# ['188', '188', '94.', 'Thierry Tornare', 'CH', '1973', 'M', '', Timedelta('4 days 22:00:09')]
#  ********************
# ['135', '135', '95.', 'Luis Madeira', 'PT', '1970', 'M', '', Timedelta('4 days 22:36:29')]
#  ********************
# ['152', '152', '95.', 'Sébastien Perseval', 'FR', '1979', 'M', '', Timedelta('4 days 22:35:51')]
#  ********************
# ['164', '164', '95.', 'Philippe Genevaux', 'FR', '1989', 'M', 'Le Ménestrail', Timedelta('4 days 22:35:54')]
#  ********************
# ['167', '167', '95.', 'Vincent Colart', 'FR', '1972', 'M', 'Vafa', Timedelta('4 days 22:36:05')]
#  ********************
# ['184', '184', '95.', 'Marc Pelisson', 'FR', '1961', 'M', '', Timedelta('4 days 22:36:17')]
#  ********************
# ['208', '208', '95.', 'Philippe Margerte', 'FR', '1964', 'M', '', Timedelta('4 days 22:35:53')]
#  ********************
# ['143', '143', '101.', 'Philippe Le Polles', 'FR', '1971', 'M', '', Timedelta('4 days 22:52:45')]
#  ********************
# ['228', '228', '102.', 'Patrick Ancrenaz', 'FR', '1965', 'M', '', Timedelta('4 days 23:11:17')]
#  ********************
# ['194', '194', '103.', 'Jerome Risso', 'FR', '1969', 'M', '', Timedelta('4 days 23:11:19')]
#  ********************
# ['195', '195', '104.', 'Jacques Andre Couret', 'FR', '1965', 'M', '', Timedelta('4 days 23:20:52')]
#  ********************
# ['148', '148', '105.', 'Olivier Lidec', 'FR', '1974', 'M', '', Timedelta('5 days 00:05:40')]
#  ********************
# ['150', '150', '106.', 'Grégory Daride', 'FR', '1980', 'M', '', Timedelta('5 days 00:29:31')]
#  ********************
# ['198', '198', '107.', 'Jerome Chamoux', 'FR', '1971', 'M', '', Timedelta('5 days 00:29:19')]
#  ********************
# ['193', '193', '108.', 'Laurent Dubois', 'FR', '1968', 'M', '', Timedelta('5 days 01:39:26')]
#  ********************
# ['212', '212', '109.', 'Pierrot Ober', 'FR', '1964', 'M', '', Timedelta('5 days 02:06:38')]
#  ********************
# ['112', '112', '110.', 'Roland Barbezat', 'CH', '1968', 'M', '', Timedelta('5 days 02:29:08')]
#  ********************
# ['204', '204', '111.', 'Charles Payen', 'FR', '1986', 'M', 'US San Giorgio', Timedelta('5 days 04:47:46')]
#  ********************
# ['137', '137', '112.', 'Jonathan Boyer', 'FR', '1986', 'M', '', Timedelta('5 days 05:23:48')]
#  ********************
# ['246', '246', '113.', 'Jean Paul Aujard', 'FR', '1967', 'M', '', Timedelta('5 days 07:14:05')]
#  ********************
# ['59', '59', '114.', 'Jerome Haguenin', 'FR', '1966', 'M', '', Timedelta('5 days 07:14:08')]
#  ********************
# ['227', '227', '115.', 'Charles Lassauce', 'CH', '1968', 'M', '', Timedelta('5 days 07:39:16')]
#  ********************
# ['210', '210', '116.', 'Laurent Rohmer', 'FR', '1967', 'M', '', Timedelta('5 days 07:49:02')]
#  ********************
# ['240', '240', '117.', 'Didier Metral', 'FR', '1979', 'M', '', Timedelta('5 days 08:03:35')]
#  ********************
# ['139', '139', '118.', 'Eric Peiry', 'CH', '1969', 'M', '', Timedelta('5 days 08:34:52')]
#  ********************
# ['186', '186', '119.', 'Tony Das Neves', 'FR', '1972', 'M', '', Timedelta('5 days 08:39:28')]
#  ********************
# ['159', '159', '120.', 'Thibaud Mathieu', 'CH', '1985', 'M', '', Timedelta('5 days 08:39:49')]
#  ********************
# ['201', '201', '121.', 'Olivier Sigrist', 'FR', '1974', 'M', 'ACEP Valréas', Timedelta('5 days 08:46:50')]
#  ********************
# ['185', '185', '122.', 'Pierre Sassoulas', 'FR', '1971', 'M', '', Timedelta('5 days 08:58:19')]
#  ********************
# ['147', '147', '123.', 'Fabian Theimert', 'DE', '1979', 'M', '', Timedelta('5 days 08:58:58')]
#  ********************
# ['290', '1406', '124.', 'Jack B Liver', 'CH', '1986', 'M', '', Timedelta('5 days 09:16:50')]
#  ********************
# ['200', '200', '125.', 'Fabrice Gueriot', 'FR', '1973', 'M', '', Timedelta('5 days 09:29:35')]
#  ********************
# ['234', '234', '126.', 'Claude Georges', 'FR', '1954', 'M', '', Timedelta('5 days 09:42:05')]
#  ********************
# ['196', '196', '127.', 'Luc Hennus', 'BE', '1961', 'M', '', Timedelta('5 days 09:53:02')]
#  ********************
# ['257', '257', '128.', 'Robin Meyer', 'FR', '1963', 'M', '', Timedelta('5 days 11:49:07')]
#  ********************
# ['244', '244', '129.', 'François Mach', 'CH', '1961', 'M', '', Timedelta('5 days 12:03:41')]
#  ********************
# ['11', '11', 'DNF', 'Krystian Pietrzak', 'PL', '1983', 'M', '', NaT]
#  ********************
# ['15', '15', 'DNF', 'Silvan Burkhalter', 'CH', '1986', 'M', '', NaT]
#  ********************
# ['16', '16', 'DNF', 'Vincent Pelisson', 'FR', '1993', 'M', 'HOKA ONE ONE Italy', NaT]
#  ********************
# ['22', '22', 'DNF', 'Sebastien Aubineau', 'FR', '1976', 'M', '', NaT]
#  ********************
# ['23', '23', 'DNF', 'Nicolas Lehmann', 'CH', '1981', 'M', '', NaT]
#  ********************
# ['26', '26', 'DNF', 'Jean-Claude Mathieu', 'FR', '1963', 'M', 'Team CERROTORRE', NaT]
#  ********************
# ['38', '38', 'DNF', 'Steve Rein', 'CH', '1982', 'M', '', NaT]
#  ********************
# ['43', '43', 'DNF', 'Christian Repitsch', 'AT', '1978', 'M', '', NaT]
#  ********************
# ['44', '44', 'DNF', 'Joe Brady', 'FR', '1983', 'M', 'BASECAMP', NaT]
#  ********************
# ['53', '53', 'DNF', 'Laurent Pelmoine', 'FR', '1966', 'M', '', NaT]
#  ********************
# ['56', '56', 'DNF', 'Sébastien Longearet', 'FR', '1978', 'M', '', NaT]
#  ********************
# ['57', '57', 'DNF', 'Alain Straumann', 'CH', '1972', 'M', '', NaT]
#  ********************
# ['62', '62', 'DNF', 'Nicolas Fragnière', 'CH', '1981', 'M', '', NaT]
#  ********************
# ['64', '64', 'DNF', 'Didier Da Costa', 'IE', '1973', 'M', '', NaT]
#  ********************
# ['66', '66', 'DNF', 'Thomas Ramoussin', 'FR', '1986', 'M', '', NaT]
#  ********************
# ['67', '67', 'DNF', 'Neil Cloke', 'GB', '1972', 'M', '', NaT]
#  ********************
# ['68', '68', 'DNF', 'Frank Buytaert', 'BE', '1971', 'M', '', NaT]
#  ********************
# ['73', '73', 'DNF', 'Yann Lecuyer', 'FR', '1975', 'M', '', NaT]
#  ********************
# ['82', '82', 'DNF', 'Nicolas Kuhn', 'FR', '1976', 'M', '', NaT]
#  ********************
# ['85', '85', 'DNF', 'Cedric Dupuich', 'FR', '1974', 'M', '', NaT]
#  ********************
# ['86', '86', 'DNF', 'Philippe Locci', 'FR', '1971', 'M', '', NaT]
#  ********************
# ['87', '87', 'DNF', 'Antoine Sillac', 'FR', '1972', 'M', '', NaT]
#  ********************
# ['89', '89', 'DNF', 'Dimitrios Ziamparas', 'GR', '1969', 'M', 'Salomon Suunto Switzerland', NaT]
#  ********************
# ['91', '91', 'DNF', 'Jeremy Loridan', 'FR', '1976', 'M', '', NaT]
#  ********************
# ['96', '96', 'DNF', 'Søren Hansen', 'DK', '1975', 'M', '', NaT]
#  ********************
# ['100', '100', 'DNF', 'Urbain Girod', 'CH', '1963', 'M', '', NaT]
#  ********************
# ['101', '101', 'DNF', 'Roberto Foelix', 'CH', '1968', 'M', '', NaT]
#  ********************
# ['106', '106', 'DNF', 'Emmanuel Van Acker', 'BE', '1971', 'M', '', NaT]
#  ********************
# ['109', '109', 'DNF', 'J-Pierre Clerissi', 'FR', '1963', 'M', '', NaT]
#  ********************
# ['128', '128', 'DNF', 'Fabien Trohay', 'FR', '1984', 'M', '', NaT]
#  ********************
# ['129', '129', 'DNF', 'Julien Compagnon', 'CH', '1990', 'M', '', NaT]
#  ********************
# ['130', '130', 'DNF', 'Philippe Tribolo', 'FR', '1975', 'M', '', NaT]
#  ********************
# ['131', '131', 'DNF', 'Jean Francois Pieri', 'FR', '1981', 'M', '', NaT]
#  ********************
# ['138', '138', 'DNF', 'Jean-Louis Yanci', 'FR', '1953', 'M', '', NaT]
#  ********************
# ['144', '144', 'DNF', 'Mael Jouan', 'FR', '1995', 'M', '', NaT]
#  ********************
# ['145', '145', 'DNF', 'Lionel Martin', 'CH', '1992', 'M', '', NaT]
#  ********************
# ['146', '146', 'DNF', 'Peter Spieler', 'CH', '1958', 'M', '', NaT]
#  ********************
# ['160', '160', 'DNF', 'Cristiano Gross', 'IT', '1974', 'M', '', NaT]
#  ********************
# ['162', '162', 'DNF', 'Urs Voegeli-Asisa', 'CH', '1964', 'M', '', NaT]
#  ********************
# ['165', '165', 'DNF', 'Régis Bardet', 'FR', '1958', 'M', '', NaT]
#  ********************
# ['166', '166', 'DNF', 'Ludovic Hublot', 'FR', '1973', 'M', '', NaT]
#  ********************
# ['172', '172', 'DNF', 'Alain Principalli', 'FR', '1967', 'M', '', NaT]
#  ********************
# ['177', '177', 'DNF', 'Jean-Marie Foubert', 'FR', '1959', 'M', 'WFU-Esprit Spiridon', NaT]
#  ********************
# ['182', '182', 'DNF', 'Alberto Calcagno', 'IT', '1972', 'M', '', NaT]
#  ********************
# ['183', '183', 'DNF', 'Thomas Champion', 'FR', '1997', 'M', '', NaT]
#  ********************
# ['203', '203', 'DNF', 'Sylvain Ait Ouarab', 'FR', '1969', 'M', '', NaT]
#  ********************
# ['205', '205', 'DNF', 'Ludovic Champion', 'FR', '1973', 'M', '', NaT]
#  ********************
# ['216', '216', 'DNF', 'Patrick Barbe', 'FR', '1971', 'M', '', NaT]
#  ********************
# ['218', '218', 'DNF', 'Milan Milanovic', 'CH', '1960', 'M', '', NaT]
#  ********************
# ['220', '220', 'DNF', 'Julien Stalder', 'CH', '1989', 'M', '', NaT]
#  ********************
# ['222', '222', 'DNF', 'Pascal Mauduit', 'FR', '1968', 'M', '', NaT]
#  ********************
# ['224', '224', 'DNF', 'Frank Benoit-Gonnin', 'FR', '1972', 'M', '', NaT]
#  ********************
# ['231', '231', 'DNF', 'Jean Rota', 'CH', '1986', 'M', '', NaT]
#  ********************
# ['232', '232', 'DNF', 'Alain Collomb', 'FR', '1964', 'M', '', NaT]
#  ********************
# ['233', '233', 'DNF', 'Frédéric Doyen', 'GA', '1966', 'M', '', NaT]
#  ********************
# ['236', '236', 'DNF', 'Claude Berruyer', 'FR', '1961', 'M', '', NaT]
#  ********************
# ['238', '238', 'DNF', 'Silvère Torre', 'FR', '1963', 'M', '', NaT]
#  ********************
# ['239', '239', 'DNF', 'Dimitar Kyosev', 'BG', '1978', 'M', '', NaT]
#  ********************
# ['241', '241', 'DNF', 'Jacques Charton', 'FR', '1979', 'M', '', NaT]
#  ********************
# ['242', '242', 'DNF', 'Thierry Carte', 'FR', '1963', 'M', '', NaT]
#  ********************
# ['243', '243', 'DNF', 'Piotr Lach', 'PL', '1974', 'M', '', NaT]
#  ********************
# ['249', '249', 'DNF', 'Basile Megali', 'FR', '1955', 'M', '', NaT]
#  ********************
# ['253', '253', 'DNF', 'Christophe Brebant', 'FR', '1960', 'M', '', NaT]
#  ********************
# ['254', '254', 'DNF', 'Sebastien Jacques', 'CH', '1989', 'M', '', NaT]
#  ********************
# ['260', '260', 'DNF', 'Pierre Weber', 'FR', '1963', 'M', '', NaT]
#  ********************
# ['261', '261', 'DNF', 'Jean Daniel Valiton', 'CH', '1954', 'M', '', NaT]
#  ********************
# ['262', '262', 'DNF', 'Gerhard Roehrl', 'DE', '1956', 'M', '', NaT]
#  ********************
# ['267', '267', 'DNF', 'Christophe Lemery', 'FR', '1967', 'M', '', NaT]
#  ********************
# ['274', '1393', 'DNF', 'Alexander Imhoff', 'CH', '1983', 'M', '', NaT]
#  ********************
# ['4', '4', 'DNS', 'Jimmy Pellegrini', 'IT', '1978', 'M', '', NaT]
#  ********************
# ['6', '6', 'DNS', 'Moisis Foltopoulos', 'GR', '1984', 'M', 'ARDASSA MOUNTAIN CLUB', NaT]
#  ********************
# ['12', '12', 'DNS', 'Johannes Schnitzer', 'DE', '1982', 'M', '', NaT]
#  ********************
# ['14', '14', 'DNS', 'Tomàs Zapata Tarifa', 'ES', '1968', 'M', '', NaT]
#  ********************
# ['33', '33', 'DNS', 'Ville Maksimainen', 'FI', '1975', 'M', '', NaT]
#  ********************
# ['39', '39', 'DNS', 'Werner Balter', 'AT', '1963', 'M', '', NaT]
#  ********************
# ['45', '45', 'DNS', 'Laurent Bourguignon', 'BE', '1971', 'M', '', NaT]
#  ********************
# ['50', '50', 'DNS', 'Nuno Santos', 'GB', '1972', 'M', '', NaT]
#  ********************
# ['60', '60', 'DNS', 'Carles Raimat Quintana', 'ES', '1972', 'M', '', NaT]
#  ********************
# ['65', '65', 'DNS', 'Christophe Heyns', 'BE', '1973', 'M', '', NaT]
#  ********************
# ['70', '70', 'DNS', "Paul O'Sullivan", 'GB', '1979', 'M', '', NaT]
#  ********************
# ['72', '72', 'DNS', 'Tatsuya Kawasaki', 'JP', '1976', 'M', '', NaT]
#  ********************
# ['78', '78', 'DNS', 'Christophe Ponce', 'FR', '1967', 'M', '', NaT]
#  ********************
# ['98', '98', 'DNS', 'Nikita Levchenko', 'RU', '1987', 'M', 'PYRRHOCORAX CAMBREMERIUS', NaT]
#  ********************
# ['103', '103', 'DNS', 'John Anderson', 'US', '1978', 'M', '', NaT]
#  ********************
# ['107', '107', 'DNS', 'Philippe Cavailles', 'FR', '1969', 'M', '', NaT]
#  ********************
# ['108', '108', 'DNS', 'Frederic Gofflot', 'BE', '1970', 'M', '', NaT]
#  ********************
# ['110', '110', 'DNS', 'Benjamin Holst', 'DK', '1970', 'M', '', NaT]
#  ********************
# ['117', '117', 'DNS', 'Gabriele Cimarosti', 'IT', '1971', 'M', 'polisportiva montereale', NaT]
#  ********************
# ['122', '122', 'DNS', 'Albert Calvó Requena', 'AD', '1970', 'M', '', NaT]
#  ********************
# ['123', '123', 'DNS', 'Edouard Dambrine', 'FR', '1983', 'M', '', NaT]
#  ********************
# ['132', '132', 'DNS', 'Oleksandr Olivson', 'UA', '1963', 'M', '', NaT]
#  ********************
# ['142', '142', 'DNS', 'Sébastien Muster', 'CH', '1970', 'M', '', NaT]
#  ********************
# ['149', '149', 'DNS', 'Xavier Bornet', 'CH', '1972', 'M', '', NaT]
#  ********************
# ['155', '155', 'DNS', 'Walter Cartelli', 'IT', '1953', 'M', '', NaT]
#  ********************
# ['168', '168', 'DNS', 'Christophe Ernst', 'BE', '1970', 'M', '', NaT]
#  ********************
# ['169', '169', 'DNS', 'Alex Mases Xifrè', 'ES', '1975', 'M', '', NaT]
#  ********************
# ['175', '175', 'DNS', 'Ulysse Lenclume', 'FR', '1976', 'M', '', NaT]
#  ********************
# ['178', '178', 'DNS', 'Martial Houot', 'FR', '1959', 'M', '', NaT]
#  ********************
# ['180', '180', 'DNS', 'Vicenç Tubau Alemany', 'ES', '1965', 'M', '', NaT]
#  ********************
# ['187', '187', 'DNS', 'Cosmin Rugina', 'RO', '1983', 'M', 'HOKA ONE ONE Switzerland', NaT]
#  ********************
# ['191', '191', 'DNS', 'Mitsuo Moriya', 'JP', '1978', 'M', '', NaT]
#  ********************
# ['199', '199', 'DNS', 'Frédéric Bernard', 'BE', '1968', 'M', '', NaT]
#  ********************
# ['207', '207', 'DNS', 'Jean Marc Clerc', 'FR', '1969', 'M', '', NaT]
#  ********************
# ['209', '209', 'DNS', 'Luciano Micheletti', 'IT', '1956', 'M', '', NaT]
#  ********************
# ['217', '217', 'DNS', 'Spyridon Siakoufis', 'GR', '1975', 'M', '', NaT]
#  ********************
# ['219', '219', 'DNS', 'Bertrand Penot', 'FR', '1970', 'M', '', NaT]
#  ********************
# ['221', '221', 'DNS', 'Antoni Martí Mases', 'ES', '1971', 'M', '', NaT]
#  ********************
# ['223', '223', 'DNS', 'Stefan Barrow', 'GB', '1976', 'M', '', NaT]
#  ********************
# ['235', '235', 'DNS', 'Jinsong Xu', 'CN', '1970', 'M', '', NaT]
#  ********************
# ['237', '237', 'DNS', 'Arno Lux', 'BE', '1966', 'M', '', NaT]
#  ********************
# ['245', '245', 'DNS', 'Marc Serradell Macau', 'ES', '1969', 'M', '', NaT]
#  ********************
# ['247', '247', 'DNS', 'Eric Perrin', 'BE', '1969', 'M', '', NaT]
#  ********************
# ['248', '248', 'DNS', 'Thomas Legrain', 'FR', '1972', 'M', '', NaT]
#  ********************
# ['252', '252', 'DNS', 'Philippe Waelti', 'CH', '1964', 'M', '', NaT]
#  ********************
# ['255', '255', 'DNS', 'Oliver Meyer', 'DE', '1973', 'M', '', NaT]
#  ********************
# ['258', '258', 'DNS', 'Patrick Turgy', 'FR', '1958', 'M', '', NaT]
#  ********************
# ['259', '259', 'DNS', 'Daniel Guillin', 'FR', '1960', 'M', '', NaT]
#  ********************
# ['263', '263', 'DNS', 'Armin Knidlberger', 'DE', '1969', 'M', '', NaT]
#  ********************
# ['264', '264', 'DNS', 'Stéphane Bonche', 'FR', '1983', 'M', '', NaT]
#  ********************
# ['265', '265', 'DNS', 'Guy-Laurent Bruttin', 'CH', '1973', 'M', '', NaT]
#  ********************
# ['268', '268', 'DNS', 'Christophe Magliano', 'FR', '1964', 'M', '', NaT]
#  ********************
# Issue [250]
# ******* delay! *******
# Fetching from: https://my1.raceresult.com/156560/RRPublish/data/list?key=2049a5fb34f5e180b9d6cf54d6150d67&listname=Online%7CFinal&page=results&contest=0&r=group&name=%231_Swiss%20Peaks%20360%0C%231_Female&f=Swiss%20Peaks%20360%0C%0C%3CIgnore%3E
# ['10', '10', '1.', 'Anita Lehmann', 'CH', '1980', 'F', '', Timedelta('3 days 13:10:45')]
#  ********************
# ['18', '18', '2.', 'Claire Bannwarth', 'FR', '1989', 'F', '', Timedelta('3 days 14:15:28')]
#  ********************
# ['48', '48', '3.', 'Emily Vaudan', 'CH', '1983', 'F', '', Timedelta('3 days 17:05:29')]
#  ********************
# ['24', '24', '4.', 'Denise Zimmermann', 'CH', '1975', 'F', '', Timedelta('3 days 20:57:41')]
#  ********************
# ['163', '163', '5.', 'Katja Fink', 'CH', '1975', 'F', '', Timedelta('3 days 22:05:22')]
#  ********************
# ['61', '61', '6.', 'Daphné Derouch', 'FR', '1989', 'F', '', Timedelta('4 days 04:41:34')]
#  ********************
# ['77', '77', '7.', 'Catherine Rion', 'CH', '1978', 'F', '', Timedelta('4 days 11:05:41')]
#  ********************
# ['225', '225', '8.', 'Perrine Fages', 'FR', '1980', 'F', '', Timedelta('4 days 12:34:44')]
#  ********************
# ['121', '121', '9.', 'Maria Ilaria Fossati', 'IT', '1972', 'F', '', Timedelta('4 days 15:48:28')]
#  ********************
# ['141', '141', '10.', 'Cornelia Hauser-Ruckli', 'CH', '1968', 'F', '', Timedelta('4 days 19:13:26')]
#  ********************
# ['213', '213', '11.', 'Virginie Duterme', 'FR', '1973', 'F', '', Timedelta('4 days 20:43:44')]
#  ********************
# ['202', '202', '12.', 'Emmanuelle Jaeglin', 'FR', '1969', 'F', '', Timedelta('5 days 07:39:15')]
#  ********************
# ['90', '90', '13.', 'Claudia Forster', 'CH', '1980', 'F', '', Timedelta('5 days 10:53:57')]
#  ********************
# ['99', '99', 'DNF', 'Sandrine Avanzato-Tarini', 'FR', '1974', 'F', '', NaT]
#  ********************
# ['170', '170', 'DNF', 'Héloïse Aeberli', 'FR', '1987', 'F', '', NaT]
#  ********************
# ['173', '173', 'DNF', 'Cindy Rosset', 'CH', '1977', 'F', '', NaT]
#  ********************
# ['189', '189', 'DNF', 'Xiabingqing Wu', 'CH', '1990', 'F', '', NaT]
#  ********************
# ['197', '197', 'DNF', 'Julie Rapenne', 'FR', '1980', 'F', '', NaT]
#  ********************
# ['206', '206', 'DNF', 'Virginie Humblet', 'BE', '1973', 'F', '', NaT]
#  ********************
# ['256', '256', 'DNF', 'Anne Ereteo', 'FR', '1967', 'F', '', NaT]
#  ********************
# ['51', '51', 'DNS', 'Dariia Bodnar', 'UA', '1984', 'F', '', NaT]
#  ********************
# ['174', '174', 'DNS', 'Keri Devine', 'NZ', '1973', 'F', '', NaT]
#  ********************
# ['214', '214', 'DNS', 'Yan Gu', 'CN', '1971', 'F', '', NaT]
#  ********************
# ['226', '226', 'DNS', 'Satu Iho', 'FI', '1984', 'F', '', NaT]
#  ********************
# ['266', '266', 'DNS', 'Magali Juvenal', 'FR', '1971', 'F', '', NaT]
#  ********************
# Issue [25]
# ******* delay! *******

# %%
SP_dem_df =  pd.DataFrame(runner_list, columns = [
    'Bib', 'Bib_2', 'Rank',
    'Name', 'Nationality',
    'Birth Year', 'Gender',
    'Club', 'Duration'])   

SP_dem_df['Status'] = SP_dem_df['Rank'].copy()
SP_dem_df['Status'] = np.where((SP_dem_df['Status'] == 'DNF') |
                               (SP_dem_df['Status'] == 'DNS')
                               , SP_dem_df['Status'], 'Finished')

SP_dem_df['Year'] = year
SP_dem_df['Race'] = 'SP360'

SP_dem_df['PK'] = SP_dem_df['Race'] +'_' + SP_dem_df['Year'] +'_' + SP_dem_df['Bib']    


SP_dem_df.head()
# Out:
#    Bib Bib_2 Rank                           Name Nationality Birth Year  \
# 0    2     2   1.                   Franco Collé          IT       1978
# 1    8     8   2.                    Jonas Russi          CH       1985
# 2    1     1   3.                Andrea Mattiato          IT       1978
# 3    3     3   4.                 Michael Nançoz          CH       1988
# 4  250   250   5.  Javier Galve Sainz De Varanda          ES       1982
#
#   Gender                  Club        Duration    Status  Year   Race  \
# 0      M  HOKA ONE ONE/ Karpos 2 days 14:45:34  Finished  2020  SP360
# 1      M                       2 days 14:45:35  Finished  2020  SP360
# 2      M                       2 days 22:32:18  Finished  2020  SP360
# 3      M                       3 days 05:08:16  Finished  2020  SP360
# 4      M                       3 days 08:19:35  Finished  2020  SP360
#
#                PK
# 0    SP360_2020_2
# 1    SP360_2020_8
# 2    SP360_2020_1
# 3    SP360_2020_3
# 4  SP360_2020_250

# %%
SP_dem_df.tail()
# Out:
#      Bib Bib_2 Rank            Name Nationality Birth Year Gender Club  \
# 270   51    51  DNS   Dariia Bodnar          UA       1984      F
# 271  174   174  DNS     Keri Devine          NZ       1973      F
# 272  214   214  DNS          Yan Gu          CN       1971      F
# 273  226   226  DNS        Satu Iho          FI       1984      F
# 274  266   266  DNS  Magali Juvenal          FR       1971      F
#
#     Duration Status  Year   Race              PK
# 270      NaT    DNS  2020  SP360   SP360_2020_51
# 271      NaT    DNS  2020  SP360  SP360_2020_174
# 272      NaT    DNS  2020  SP360  SP360_2020_214
# 273      NaT    DNS  2020  SP360  SP360_2020_226
# 274      NaT    DNS  2020  SP360  SP360_2020_266

# %%
SP_dem_df['Duration'] = SP_dem_df['Duration'].astype('str') 
SP_dem_df.to_excel(f'Data/SwissPeaks360_{year}_DEM.xlsx', index=False)

# %%
SP_dem_df[SP_dem_df['Status'] == 'DNF']
# Out:
#      Bib Bib_2 Rank                Name Nationality Birth Year Gender  \
# 129   11    11  DNF   Krystian Pietrzak          PL       1983      M
# 130   15    15  DNF   Silvan Burkhalter          CH       1986      M
# 131   16    16  DNF    Vincent Pelisson          FR       1993      M
# 132   22    22  DNF  Sebastien Aubineau          FR       1976      M
# 133   23    23  DNF     Nicolas Lehmann          CH       1981      M
# ..   ...   ...  ...                 ...         ...        ...    ...
# 265  173   173  DNF        Cindy Rosset          CH       1977      F
# 266  189   189  DNF      Xiabingqing Wu          CH       1990      F
# 267  197   197  DNF       Julie Rapenne          FR       1980      F
# 268  206   206  DNF    Virginie Humblet          BE       1973      F
# 269  256   256  DNF         Anne Ereteo          FR       1967      F
#
#                    Club Duration Status  Year   Race              PK
# 129                          NaT    DNF  2020  SP360   SP360_2020_11
# 130                          NaT    DNF  2020  SP360   SP360_2020_15
# 131  HOKA ONE ONE Italy      NaT    DNF  2020  SP360   SP360_2020_16
# 132                          NaT    DNF  2020  SP360   SP360_2020_22
# 133                          NaT    DNF  2020  SP360   SP360_2020_23
# ..                  ...      ...    ...   ...    ...             ...
# 265                          NaT    DNF  2020  SP360  SP360_2020_173
# 266                          NaT    DNF  2020  SP360  SP360_2020_189
# 267                          NaT    DNF  2020  SP360  SP360_2020_197
# 268                          NaT    DNF  2020  SP360  SP360_2020_206
# 269                          NaT    DNF  2020  SP360  SP360_2020_256
#
# [76 rows x 13 columns]

# %% [markdown]
# ### Using bib column to extract station

# %%
list(SP_dem_df['ID'].unique())[:1]

# %%
station_list = []
failed_to_fetch= []
n=0
# Loop through the unique bibs in the DataFrame
for unique_id in list(SP_dem_df['ID'].unique()):  # Limit to just one bib for testing
    n = n+1
    print(n, ' - ', unique_id)
    
    # URL of the JSON file
    url = f'https://my4.raceresult.com/156560/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid={unique_id}'
    print(url)

    # Send a GET request to fetch the JSON data
    response = requests.get(url)

    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        # Parse the JSON data
        data = response.json()
        stations = data['Splits']
        
        # Loop through the stations
        for station in stations:
            station_name = station['Name']
            exists = station['Exists']
            
            # Helper function to format durations safely
            def get_formatted_duration(key):
                duration = station.get(key)
                if duration:
                    return f"{duration.split(':')[0]} days {':'.join(duration.split(':')[1:])}"
                return np.nan

            formatted_gun = get_formatted_duration('Gun')
            formatted_chip = get_formatted_duration('Chip')
            formatted_sector = get_formatted_duration('Sector')

            # Store the extracted info in the station list
            extracted_info = [unique_id, station_name, exists,
                              formatted_gun, 
                              formatted_chip,
                              formatted_sector]
            station_list.append(extracted_info)
            
    else:
        print(f"Failed to fetch data for {unique_id}. Status code: {response.status_code}")
        failed_to_fetch.append(unique_id)
        
    
    #### So we dont get blocked!!!!
    delay_seconds = random.randint(5,20)
    print('Delay before calling the server again: ', delay_seconds)
    print('*'*20)
    time.sleep(delay_seconds)

# %%
# Convert the station list to a DataFrame
aid_station_df = pd.DataFrame(station_list, columns=['Bib', 'Aid Station', 'Aid Station Duration', 'Rolling Duration'])
aid_station_df['Year'] = year
aid_station_df['Race'] = 'SP360'

aid_station_df['PK'] = aid_station_df['Race'] +'_' + aid_station_df['Year'] +'_' + aid_station_df['Bib']    

# Preview the DataFrame
print(aid_station_df.head())
# aid_station_df.to_excel(f'Data/SwissPeaks360_{year}_aid_stations.xlsx', index=False)

# %%
aid_station_df['Aid Station'].unique()

# %%
aid_station_df.to_excel(f'Data/SwissPeaks360_{year}_aid_stations.xlsx', index=False)

# %%
# End the timer
end_time = time.time()

# Calculate and print execution time
execution_time = end_time - start_time
print(f"Execution time: {execution_time:.6f} seconds")
