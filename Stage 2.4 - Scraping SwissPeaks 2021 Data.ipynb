# %% [markdown]
# # SwissPeaks Data
#
# In this code, Swiss Peaks website is scraped. The raw data is then saved to a folder with race and year. No cleaning is done.

# %%
import requests
import json
import html
import pandas as pd
import time
import re
import unicodedata
import datetime
import random
import numpy as np
from datetime import timedelta

# Start the timer
start_time = time.time()

year = '2021'
male_url = 'https://my4.raceresult.com/161079/RRPublish/data/list?key=374250657b42ce1a7a8e1a4a3311786d&listname=Result%20Lists%7CProv.%20Gender%20Results%20360&page=results&contest=1&r=group&name=%232_Male&f='
female_url = 'https://my4.raceresult.com/161079/RRPublish/data/list?key=374250657b42ce1a7a8e1a4a3311786d&listname=Result%20Lists%7CProv.%20Gender%20Results%20360&page=results&contest=1&r=group&name=%231_Female&f='
delay_seconds = 15

# %% [markdown]
# ## Scraping Swiss Peaks 2021 Data from the website

# %%
def reformat_name(name_str):
    parts = [p.strip() for p in name_str.split(',')]
    return f"{parts[1]} {parts[0]}" if len(parts) == 2 else name_str


runner_list = []

for url in [male_url, female_url]:
    print(f"Fetching from: {url}")
    
    # Send GET request
    response = requests.get(url)

    if response.status_code == 200:
        json_data = response.json()
        
        # Extract the specific race data
        race_participants = json_data['data']
    #     print(race_participants)
        extracted_list = []

        for participant in race_participants:
            
            try:
                bib =  participant[0]
                ID =  participant[1]
                status =  participant[2]                
            
                # Format name
                formatted_name = reformat_name(participant[3])
                formatted_name = formatted_name.title()
                
                match = re.search(r'\[img:flags/([A-Z]{2})\.gif\]', participant[4])
                country_code = match.group(1) if match else ""
                
                birth_year =  participant[5]               
                age_gender = participant[6]
                club =  participant[7]       
                
                # Convert time
                raw_time = participant[8]
                formatted_time = pd.to_timedelta(raw_time)
#                 print(formatted_time)    
                
                
                runner_info = [bib, ID, status, formatted_name, 
                               country_code,age_gender, 
                                birth_year, club, formatted_time ]
                print(runner_info, '\n', '*'*20)
                runner_list.append(runner_info)
            except:
                print(participant)


    else:
        print(f"Failed to retrieve data. Status code: {response.status_code}")

    time.sleep(delay_seconds)
# Out:
# Fetching from: https://my4.raceresult.com/161079/RRPublish/data/list?key=374250657b42ce1a7a8e1a4a3311786d&listname=Result%20Lists%7CProv.%20Gender%20Results%20360&page=results&contest=1&r=group&name=%232_Male&f=
# ['2', '14362', '1.', 'Peter Kienzl', 'IT', 'Master 1 Hommes', '1975', 'Hoka / Dynafit', Timedelta('3 days 14:34:28')]
#  ********************
# ['4', '12489', '2.', 'Michael Nançoz', 'CH', 'Seniors Hommes', '1988', '', Timedelta('3 days 21:51:22')]
#  ********************
# ['369', '14181', '3.', 'Hendrik Spoering', 'DE', 'Seniors Hommes', '1990', '', Timedelta('4 days 03:18:46')]
#  ********************
# ['36', '12514', '4.', 'Nicolas Bie', 'FR', 'Master 1 Hommes', '1977', '', Timedelta('4 days 04:37:23')]
#  ********************
# ['13', '14065', '5.', 'Lucas Papi', 'IT', 'Master 1 Hommes', '1980', '', Timedelta('4 days 05:21:47')]
#  ********************
# ['11', '14366', '6.', 'Brice Jacquot', 'FR', 'Master 1 Hommes', '1980', 'Hoka', Timedelta('4 days 06:14:19')]
#  ********************
# ['290', '13522', '7.', 'Javier Galve', 'ES', 'Seniors Hommes', '1982', '', Timedelta('4 days 07:30:28')]
#  ********************
# ['107', '12591', '8.', 'Laurent Pelmoine', 'FR', 'Master 2 Hommes', '1966', '', Timedelta('4 days 09:35:10')]
#  ********************
# ['267', '13461', '9.', 'Olivier Bourdais', 'FR', 'Master 2 Hommes', '1971', '', Timedelta('4 days 10:30:56')]
#  ********************
# ['317', '13657', '10.', 'Paul Henri Romestin', 'FR', 'Seniors Hommes', '1982', '', Timedelta('4 days 11:01:32')]
#  ********************
# ['264', '13455', '11.', 'Thierry Ador', 'FR', 'Master 2 Hommes', '1971', '', Timedelta('4 days 13:17:48')]
#  ********************
# ['100', '12584', '12.', 'Matthieu Moreau', 'FR', 'Master 1 Hommes', '1980', '', Timedelta('4 days 13:17:52')]
#  ********************
# ['370', '14204', '13.', 'Luca Guerini', 'IT', 'Master 2 Hommes', '1966', '', Timedelta('4 days 14:16:22')]
#  ********************
# ['282', '13491', '14.', 'Jonas Biland', 'CH', 'Seniors Hommes', '1988', '', Timedelta('4 days 17:44:25')]
#  ********************
# ['300', '13585', '15.', 'Andi Mami?', 'SI', 'Master 1 Hommes', '1977', '', Timedelta('4 days 18:25:22')]
#  ********************
# ['228', '13363', '16.', 'Bastien Deliau', 'FR', 'Master 1 Hommes', '1974', '', Timedelta('4 days 18:38:14')]
#  ********************
# ['270', '13465', '17.', 'Fabien Danet', 'FR', 'Master 1 Hommes', '1974', '', Timedelta('4 days 19:14:13')]
#  ********************
# ['35', '12513', '18.', 'Rémy Duperray', 'FR', 'Master 1 Hommes', '1976', '', Timedelta('4 days 19:25:53')]
#  ********************
# ['373', '14336', '19.', 'Francesco Zacchè', 'IT', 'Seniors Hommes', '1997', '', Timedelta('4 days 19:26:20')]
#  ********************
# ['68', '12548', '20.', 'Pirin Galov', 'BG', 'Master 1 Hommes', '1974', '', Timedelta('4 days 20:36:50')]
#  ********************
# ['326', '13721', '21.', 'Sébastien Arnould', 'FR', 'Seniors Hommes', '1986', '', Timedelta('4 days 20:39:28')]
#  ********************
# ['303', '13604', '22.', 'Pierre-Henri Jouneau', 'FR', 'Master 2 Hommes', '1965', '', Timedelta('4 days 20:40:48')]
#  ********************
# ['262', '13446', '23.', 'Dries Ampe', 'BE', 'Master 2 Hommes', '1970', '', Timedelta('4 days 20:51:32')]
#  ********************
# ['173', '12661', '24.', 'Joachim Bühler', 'CH', 'Master 1 Hommes', '1972', '', Timedelta('4 days 21:04:32')]
#  ********************
# ['224', '12713', '25.', 'Adrien Schluchter', 'CH', 'Master 3 Hommes', '1954', '', Timedelta('4 days 22:49:36')]
#  ********************
# ['59', '12538', '26.', 'Laurent Grucker', 'FR', 'Master 1 Hommes', '1973', '', Timedelta('4 days 23:20:00')]
#  ********************
# ['250', '13406', '27.', 'Kurt Nadler', 'CH', 'Master 2 Hommes', '1967', '', Timedelta('4 days 23:55:29')]
#  ********************
# ['265', '13456', '27.', 'Yannick Chédel', 'CH', 'Master 1 Hommes', '1973', '', Timedelta('4 days 23:55:29')]
#  ********************
# ['197', '12685', '29.', "Paul O'Sullivan", 'GB', 'Master 1 Hommes', '1979', '', Timedelta('5 days 00:13:10')]
#  ********************
# ['20', '12498', '30.', 'Raphael Curtil', 'FR', 'Master 1 Hommes', '1974', '', Timedelta('5 days 00:59:51')]
#  ********************
# ['60', '12539', '31.', 'Gilles Le Mouel', 'FR', 'Master 1 Hommes', '1972', '', Timedelta('5 days 00:59:53')]
#  ********************
# ['375', '14360', '32.', 'Patrick Lauraux', 'CH', 'Master 2 Hommes', '1971', '', Timedelta('5 days 01:09:45')]
#  ********************
# ['82', '12563', '33.', 'Krystian Pietrzak', 'PL', 'Seniors Hommes', '1983', '', Timedelta('5 days 01:57:19')]
#  ********************
# ['256', '13420', '34.', 'Philippe Locci', 'FR', 'Master 2 Hommes', '1971', '', Timedelta('5 days 02:04:20')]
#  ********************
# ['137', '12623', '35.', 'Christian Fatton', 'CH', 'Master 3 Hommes', '1959', '', Timedelta('5 days 02:06:33')]
#  ********************
# ['225', '12714', '36.', 'Carlos Gomez Bravo', 'CL', 'Master 2 Hommes', '1971', '', Timedelta('5 days 02:20:32')]
#  ********************
# ['343', '13825', '37.', 'Sergio Minoggio', 'IT', 'Master 2 Hommes', '1965', '', Timedelta('5 days 02:30:18')]
#  ********************
# ['88', '12570', '38.', 'Lucas Probst', 'FR', 'Seniors Hommes', '1997', '', Timedelta('5 days 02:30:19')]
#  ********************
# ['75', '12556', '39.', 'Paul Moog', 'FR', 'Master 2 Hommes', '1969', '', Timedelta('5 days 02:41:08')]
#  ********************
# ['44', '12522', '40.', 'Julien Carlier', 'FR', 'Master 1 Hommes', '1979', '', Timedelta('5 days 02:48:27')]
#  ********************
# ['347', '13888', '40.', 'Michael Carraz', 'FR', 'Master 1 Hommes', '1981', '', Timedelta('5 days 02:48:27')]
#  ********************
# ['222', '12711', '42.', 'Xavier Amey', 'FR', 'Master 1 Hommes', '1974', '', Timedelta('5 days 02:50:39')]
#  ********************
# ['371', '14260', '43.', 'Franck Dorne', 'FR', 'Master 2 Hommes', '1964', '', Timedelta('5 days 03:24:06')]
#  ********************
# ['377', '13438', '44.', 'Carles Solivera', 'ES', 'Master 2 Hommes', '1971', '', Timedelta('5 days 03:33:08')]
#  ********************
# ['17', '12495', '45.', 'Jérôme Pellé', 'FR', 'Master 1 Hommes', '1975', '', Timedelta('5 days 03:34:52')]
#  ********************
# ['287', '13512', '45.', 'François Ligney', 'FR', 'Master 2 Hommes', '1962', '', Timedelta('5 days 03:34:52')]
#  ********************
# ['219', '12708', '47.', 'Jean-Sebastien Mayen', 'FR', 'Seniors Hommes', '1986', '', Timedelta('5 days 03:57:07')]
#  ********************
# ['67', '12546', '48.', 'Pierre Dechnik', 'FR', 'Master 1 Hommes', '1974', '', Timedelta('5 days 04:23:34')]
#  ********************
# ['227', '13362', '49.', 'Nicholas Turin', 'CH', 'Master 1 Hommes', '1972', '', Timedelta('5 days 04:37:16')]
#  ********************
# ['150', '12636', '50.', 'Victor Hugo Do Carmo', 'PT', 'Master 2 Hommes', '1971', '', Timedelta('5 days 04:45:20')]
#  ********************
# ['52', '12531', '51.', 'Volker Fohrmeister', 'DE', 'Seniors Hommes', '1985', '', Timedelta('5 days 04:55:09')]
#  ********************
# ['69', '12549', '52.', 'Anthony Samain', 'BE', 'Master 2 Hommes', '1969', '', Timedelta('5 days 05:03:44')]
#  ********************
# ['298', '13571', '53.', 'Patrick Goeringer', 'CH', 'Master 2 Hommes', '1967', '', Timedelta('5 days 05:09:55')]
#  ********************
# ['145', '12631', '54.', 'Julien Compagnon', 'CH', 'Seniors Hommes', '1990', '', Timedelta('5 days 05:18:28')]
#  ********************
# ['318', '13674', '55.', 'Jeremy Loridan', 'FR', 'Master 1 Hommes', '1976', '', Timedelta('5 days 05:49:32')]
#  ********************
# ['196', '12684', '56.', 'Oliver Meyer', 'DE', 'Master 1 Hommes', '1973', '', Timedelta('5 days 06:17:42')]
#  ********************
# ['121', '12606', '57.', 'Thomas Bigotto-Thouvenin', 'FR', 'Seniors Hommes', '1988', '', Timedelta('5 days 06:31:53')]
#  ********************
# ['126', '12612', '58.', 'Tomasz Sadowski', 'PL', 'Master 1 Hommes', '1977', '', Timedelta('5 days 06:35:46')]
#  ********************
# ['186', '12674', '59.', 'Oleksandr Olivson', 'UA', 'Master 2 Hommes', '1963', '', Timedelta('5 days 06:54:06')]
#  ********************
# ['123', '12608', '60.', 'Florian Clerc', 'FR', 'Seniors Hommes', '1992', '', Timedelta('5 days 07:10:35')]
#  ********************
# ['247', '13402', '61.', 'Pierre-André Maillard', 'CH', 'Master 3 Hommes', '1961', '', Timedelta('5 days 07:42:08')]
#  ********************
# ['38', '12516', '62.', 'Jeremy Boil', 'FR', 'Seniors Hommes', '1983', '', Timedelta('5 days 08:29:51')]
#  ********************
# ['255', '13414', '62.', 'Antoine Doutté', 'FR', 'Master 1 Hommes', '1977', '', Timedelta('5 days 08:29:51')]
#  ********************
# ['260', '13432', '62.', 'Damien Vesseau', 'FR', 'Master 1 Hommes', '1980', '', Timedelta('5 days 08:29:51')]
#  ********************
# ['135', '12621', '65.', 'Graham Nash', 'GB', 'Master 2 Hommes', '1969', '', Timedelta('5 days 08:34:39')]
#  ********************
# ['31', '12509', '66.', 'Matthew Davis', 'GB', 'Master 2 Hommes', '1970', '', Timedelta('5 days 08:34:40')]
#  ********************
# ['127', '12613', '67.', 'Florent Maire', 'FR', 'Master 2 Hommes', '1967', '', Timedelta('5 days 09:10:28')]
#  ********************
# ['99', '12583', '68.', 'Jean-Luc Gillet', 'FR', 'Master 3 Hommes', '1961', '', Timedelta('5 days 09:10:29')]
#  ********************
# ['90', '12572', '69.', 'Stephane Alleguede', 'FR', 'Master 1 Hommes', '1972', '', Timedelta('5 days 09:16:28')]
#  ********************
# ['149', '12635', '70.', 'Laurent Lambert', 'FR', 'Master 2 Hommes', '1970', '', Timedelta('5 days 09:20:55')]
#  ********************
# ['341', '13818', '71.', 'Thomas Quirk', 'CH', 'Master 1 Hommes', '1975', '', Timedelta('5 days 09:27:12')]
#  ********************
# ['319', '13676', '72.', 'Antoine Sillac', 'FR', 'Master 1 Hommes', '1972', '', Timedelta('5 days 09:28:59')]
#  ********************
# ['65', '12544', '73.', 'Mikaël Guillermo', 'FR', 'Master 1 Hommes', '1973', '', Timedelta('5 days 10:21:37')]
#  ********************
# ['243', '13395', '74.', 'Davide Ferrara', 'IT', 'Master 2 Hommes', '1969', '', Timedelta('5 days 10:27:01')]
#  ********************
# ['163', '12650', '75.', 'Gilles Samuel', 'CH', 'Master 1 Hommes', '1978', '', Timedelta('5 days 10:50:47')]
#  ********************
# ['93', '12575', '76.', 'Vittorio Benvenuti', 'IT', 'Master 2 Hommes', '1964', '', Timedelta('5 days 11:32:42')]
#  ********************
# ['86', '12568', '77.', 'Massimo Rabito', 'IT', 'Master 3 Hommes', '1961', '', Timedelta('5 days 11:32:44')]
#  ********************
# ['215', '12704', '78.', 'Philippe Tribolo', 'FR', 'Master 1 Hommes', '1975', '', Timedelta('5 days 12:03:12')]
#  ********************
# ['212', '12700', '79.', 'Derek Fish', 'GB', 'Master 1 Hommes', '1976', '', Timedelta('5 days 12:19:09')]
#  ********************
# ['138', '12624', '80.', 'Lionel Martin', 'CH', 'Seniors Hommes', '1992', '', Timedelta('5 days 13:00:36')]
#  ********************
# ['344', '13833', '81.', 'Yann Lamy', 'CA', 'Master 2 Hommes', '1971', '', Timedelta('5 days 13:13:35')]
#  ********************
# ['213', '12702', '82.', 'David Fernandez Fuertes', 'ES', 'Master 1 Hommes', '1979', '', Timedelta('5 days 15:48:28')]
#  ********************
# ['104', '12588', '83.', 'Francesco Damiani', 'IT', 'Master 1 Hommes', '1979', '', Timedelta('5 days 16:08:46')]
#  ********************
# ['192', '12680', '84.', 'Christophe Heyns', 'BE', 'Master 1 Hommes', '1973', '', Timedelta('5 days 16:37:26')]
#  ********************
# ['115', '12599', '85.', 'Olivier Jouffrey', 'FR', 'Master 2 Hommes', '1970', '', Timedelta('5 days 16:40:00')]
#  ********************
# ['113', '12597', '86.', 'Neil Cloke', 'GB', 'Master 1 Hommes', '1972', '', Timedelta('5 days 16:55:30')]
#  ********************
# ['183', '12671', '87.', 'Albert Calvó Requena', 'AD', 'Master 2 Hommes', '1970', '', Timedelta('5 days 17:06:34')]
#  ********************
# ['23', '12501', '88.', 'Julien Didier', 'FR', 'Master 1 Hommes', '1981', '', Timedelta('5 days 17:14:00')]
#  ********************
# ['248', '13403', '89.', 'Vasco Bras', 'PT', 'Master 1 Hommes', '1981', '', Timedelta('5 days 17:55:16')]
#  ********************
# ['245', '13398', '90.', 'Obreza Marko', 'SI', 'Master 2 Hommes', '1967', '', Timedelta('5 days 18:44:08')]
#  ********************
# ['269', '13464', '91.', 'Jerome Haguenin', 'FR', 'Master 2 Hommes', '1966', '', Timedelta('5 days 18:44:09')]
#  ********************
# ['355', '13965', '92.', 'Philippe Hoarau', 'FR', 'Master 1 Hommes', '1974', '', Timedelta('5 days 18:52:02')]
#  ********************
# ['273', '13471', '93.', 'Bernard Denis', 'BE', 'Master 1 Hommes', '1975', '', Timedelta('5 days 19:09:12')]
#  ********************
# ['166', '12653', '94.', 'Olivier Dormond', 'CH', 'Master 1 Hommes', '1973', '', Timedelta('5 days 19:36:57')]
#  ********************
# ['305', '13606', '95.', 'Romain Jouffroy', 'FR', 'Master 1 Hommes', '1978', '', Timedelta('5 days 19:42:35')]
#  ********************
# ['134', '12620', '96.', 'Stefano Flamia', 'IT', 'Master 1 Hommes', '1975', '', Timedelta('5 days 19:50:28')]
#  ********************
# ['79', '12560', '97.', 'Severino Lodi', 'IT', 'Master 2 Hommes', '1967', '', Timedelta('5 days 20:16:25')]
#  ********************
# ['37', '12515', '98.', 'Thierry Incerti', 'FR', 'Master 2 Hommes', '1970', '', Timedelta('5 days 20:38:37')]
#  ********************
# ['254', '13413', '99.', 'Arnault Fontaine', 'FR', 'Master 1 Hommes', '1974', '', Timedelta('5 days 21:34:13')]
#  ********************
# ['188', '12676', '100.', 'Frédéric Gofflot', 'BE', 'Master 2 Hommes', '1970', '', Timedelta('5 days 21:36:05')]
#  ********************
# ['189', '12677', '101.', 'Laurent Bourguignon', 'BE', 'Master 2 Hommes', '1971', '', Timedelta('5 days 21:36:06')]
#  ********************
# ['364', '14068', '102.', 'Laurent Rohmer', 'FR', 'Master 2 Hommes', '1967', '', Timedelta('5 days 21:59:41')]
#  ********************
# ['122', '12607', '103.', 'Mathias Kunze', 'DE', 'Master 2 Hommes', '1971', '', Timedelta('5 days 22:20:22')]
#  ********************
# ['92', '12574', '104.', 'Nicolas Kuhn', 'FR', 'Master 1 Hommes', '1976', '', Timedelta('5 days 22:42:12')]
#  ********************
# ['152', '12638', '105.', 'Pascal Gevisier', 'CH', 'Master 2 Hommes', '1969', '', Timedelta('5 days 22:50:52')]
#  ********************
# ['263', '13449', '106.', 'Laurent Perisset', 'CH', 'Seniors Hommes', '1982', '', Timedelta('5 days 23:00:51')]
#  ********************
# ['331', '13768', '107.', 'Igor Sarzi Sartori', 'AT', 'Master 2 Hommes', '1971', '', Timedelta('5 days 23:29:03')]
#  ********************
# ['259', '13431', '108.', 'Josep Roig', 'AD', 'Master 1 Hommes', '1972', '', Timedelta('5 days 23:40:52')]
#  ********************
# ['26', '12504', '109.', 'Daniel Rojo', 'ES', 'Master 2 Hommes', '1970', '', Timedelta('6 days 00:01:30')]
#  ********************
# ['84', '12565', '110.', 'Gaëtan Husson', 'FR', 'Master 1 Hommes', '1973', '', Timedelta('6 days 00:33:03')]
#  ********************
# ['281', '13489', '111.', 'Jacob Nonval', 'RE', 'Master 2 Hommes', '1971', '', Timedelta('6 days 00:43:00')]
#  ********************
# ['280', '13486', '112.', 'Lionel Berteau', 'FR', 'Master 2 Hommes', '1966', '', Timedelta('6 days 00:51:36')]
#  ********************
# ['155', '12642', '113.', 'Jean Rota', 'CH', 'Seniors Hommes', '1986', '', Timedelta('6 days 01:16:10')]
#  ********************
# ['360', '14005', '114.', 'Julien Mathieu', 'FR', 'Master 1 Hommes', '1978', '', Timedelta('6 days 01:35:37')]
#  ********************
# ['157', '12644', '115.', 'Keith Shaw', 'GB', 'Master 1 Hommes', '1981', '', Timedelta('6 days 01:39:01')]
#  ********************
# ['12', '14367', '116.', 'Paul Wathan', 'GB', 'Seniors Hommes', '1988', 'Hoka', Timedelta('6 days 01:45:04')]
#  ********************
# ['221', '12710', '117.', 'Olivier Gaudin', 'FR', 'Master 1 Hommes', '1973', '', Timedelta('6 days 01:46:09')]
#  ********************
# ['209', '12697', '118.', 'Vicenç Tubau Alemany', 'ES', 'Master 2 Hommes', '1965', '', Timedelta('6 days 02:04:05')]
#  ********************
# ['345', '13854', '119.', 'Ouns Kissiyar', 'BE', 'Master 1 Hommes', '1974', '', Timedelta('6 days 02:04:37')]
#  ********************
# ['357', '13993', '120.', 'Jacek Fugiel', 'PL', 'Master 2 Hommes', '1962', '', Timedelta('6 days 02:18:48')]
#  ********************
# ['236', '13382', '121.', 'Franck Joubert', 'FR', 'Master 2 Hommes', '1967', '', Timedelta('6 days 02:21:32')]
#  ********************
# ['237', '13383', '121.', 'Christophe Couchoud', 'FR', 'Master 2 Hommes', '1968', '', Timedelta('6 days 02:21:32')]
#  ********************
# ['275', '13473', '123.', 'Dominique Luc', 'BE', 'Master 2 Hommes', '1969', '', Timedelta('6 days 02:32:55')]
#  ********************
# ['220', '12709', '124.', 'Yvan Melennec', 'FR', 'Master 1 Hommes', '1976', '', Timedelta('6 days 02:32:56')]
#  ********************
# ['315', '13647', '125.', 'Michail Kushner', 'IL', 'Master 2 Hommes', '1962', '', Timedelta('6 days 02:34:17')]
#  ********************
# ['327', '13735', '126.', 'Christophe Goilot', 'FR', 'Master 2 Hommes', '1966', '', Timedelta('6 days 02:45:34')]
#  ********************
# ['80', '12561', '127.', 'Erick Clairon', 'FR', 'Master 2 Hommes', '1968', '', Timedelta('6 days 02:45:36')]
#  ********************
# ['124', '12610', '128.', 'Fabien Grilot', 'FR', 'Seniors Hommes', '1987', '', Timedelta('6 days 02:52:48')]
#  ********************
# ['18', '12496', '129.', 'Andrea Palma', 'IT', 'Master 1 Hommes', '1972', '', Timedelta('6 days 03:29:30')]
#  ********************
# ['217', '12706', '129.', 'Carlo De Amici', 'IT', 'Master 2 Hommes', '1967', '', Timedelta('6 days 03:29:30')]
#  ********************
# ['45', '12523', '131.', 'Didier Latreille', 'FR', 'Master 1 Hommes', '1976', '', Timedelta('6 days 03:30:04')]
#  ********************
# ['168', '12655', '132.', 'Xavier Robyr', 'CH', 'Master 2 Hommes', '1969', '', Timedelta('6 days 03:31:49')]
#  ********************
# ['306', '13611', '133.', 'Marco Loyen', 'FR', 'Master 1 Hommes', '1981', '', Timedelta('6 days 03:32:54')]
#  ********************
# ['14', '12492', '134.', 'Andréa Braga', 'BE', 'Seniors Hommes', '1988', '', Timedelta('6 days 03:33:56')]
#  ********************
# ['144', '12630', '135.', 'Alexandre Borr', 'FR', 'Master 1 Hommes', '1979', '', Timedelta('6 days 03:34:18')]
#  ********************
# ['27', '12505', '136.', 'Philippe Margerte', 'FR', 'Master 2 Hommes', '1964', '', Timedelta('6 days 04:04:14')]
#  ********************
# ['118', '12603', '137.', 'Matthias Barsch', 'DE', 'Master 1 Hommes', '1978', '', Timedelta('6 days 04:26:16')]
#  ********************
# ['292', '13527', '138.', 'Paolo Bosco', 'IT', 'Seniors Hommes', '1985', '', Timedelta('6 days 04:43:54')]
#  ********************
# ['252', '13409', '139.', 'Olivier Sigrist', 'FR', 'Master 1 Hommes', '1974', '', Timedelta('6 days 04:47:04')]
#  ********************
# ['194', '12682', '140.', 'Stéphane Galeazzi', 'FR', 'Master 2 Hommes', '1964', '', Timedelta('6 days 04:48:25')]
#  ********************
# ['62', '12541', '141.', 'Laurent Facile', 'FR', 'Master 1 Hommes', '1974', '', Timedelta('6 days 04:59:09')]
#  ********************
# ['73', '12554', '142.', 'Bruno De Paoli', 'FR', 'Master 2 Hommes', '1963', '', Timedelta('6 days 04:59:11')]
#  ********************
# ['352', '13954', '143.', 'Charles Masset', 'BE', 'Seniors Hommes', '1996', '', Timedelta('6 days 05:12:16')]
#  ********************
# ['253', '13411', '144.', 'Frédéric Grand', 'FR', 'Master 2 Hommes', '1966', '', Timedelta('6 days 05:40:46')]
#  ********************
# ['141', '12627', '145.', 'Mauro Cornaz', 'IT', 'Master 3 Hommes', '1960', '', Timedelta('6 days 05:55:43')]
#  ********************
# ['258', '13426', '145.', 'Diego Milani', 'IT', 'Master 2 Hommes', '1971', '', Timedelta('6 days 05:55:43')]
#  ********************
# ['311', '13626', '145.', 'Andrea Raso', 'IT', 'Master 2 Hommes', '1971', '', Timedelta('6 days 05:55:43')]
#  ********************
# ['143', '12629', '148.', 'Gianluca Di Giannantonio', 'IT', 'Master 2 Hommes', '1967', '', Timedelta('6 days 05:55:46')]
#  ********************
# ['346', '13885', '149.', 'Lodovico Tora', 'IT', 'Master 2 Hommes', '1965', '', Timedelta('6 days 05:59:40')]
#  ********************
# ['146', '12632', '150.', 'Alexander Imhoff', 'CH', 'Seniors Hommes', '1983', '', Timedelta('6 days 06:03:58')]
#  ********************
# ['277', '13483', '151.', 'Loïc Val', 'FR', 'Seniors Hommes', '1986', '', Timedelta('6 days 06:05:07')]
#  ********************
# ['285', '13498', '152.', 'Jean-Louis Freret', 'FR', 'Master 2 Hommes', '1968', '', Timedelta('6 days 06:15:12')]
#  ********************
# ['238', '13384', '153.', 'Charles Lassauce', 'CH', 'Master 2 Hommes', '1968', '', Timedelta('6 days 06:32:30')]
#  ********************
# ['356', '13982', '154.', 'Thierry Ginisty', 'FR', 'Master 2 Hommes', '1967', '', Timedelta('6 days 06:54:49')]
#  ********************
# ['350', '13938', '155.', 'Gaël Roser', 'FR', 'Master 1 Hommes', '1976', '', Timedelta('6 days 07:05:53')]
#  ********************
# ['278', '13484', '156.', 'Eric Cote', 'CA', 'Master 2 Hommes', '1966', '', Timedelta('6 days 07:24:57')]
#  ********************
# ['293', '13529', '157.', 'Christophe Reynard', 'FR', 'Master 2 Hommes', '1969', '', Timedelta('6 days 07:35:45')]
#  ********************
# ['234', '13379', '158.', 'Fabio Caporali', 'IT', 'Master 1 Hommes', '1981', '', Timedelta('6 days 07:40:24')]
#  ********************
# ['381', '13488', '158.', 'Miodrag Vujković', 'SI', 'Master 1 Hommes', '1979', '', Timedelta('6 days 07:40:24')]
#  ********************
# ['368', '14153', '160.', 'Etienne Scolas', 'BE', 'Master 1 Hommes', '1980', '', Timedelta('6 days 08:07:36')]
#  ********************
# ['323', '13712', '161.', 'Luciano Piazza', 'IT', 'Master 2 Hommes', '1962', '', Timedelta('6 days 08:55:47')]
#  ********************
# ['22', '12500', '162.', 'Paul Tanne', 'FR', 'Master 3 Hommes', '1959', '', Timedelta('6 days 09:15:39')]
#  ********************
# ['97', '12581', '163.', 'Laurent Ghio', 'FR', 'Master 2 Hommes', '1970', '', Timedelta('6 days 10:38:51')]
#  ********************
# ['363', '14063', '164.', 'Stan Townsend', 'GB', 'Seniors Hommes', '1993', '', Timedelta('6 days 11:18:06')]
#  ********************
# ['3', '13380', 'DNF', 'Serge Lattion', 'CH', 'Master 1 Hommes', '1973', '', NaT]
#  ********************
# ['6', '14408', 'DNF', 'Joachim Pellissier', 'CH', 'Master 1 Hommes', '1978', '', NaT]
#  ********************
# ['10', '14488', 'DNF', 'Jack B Liver', 'CH', 'Seniors Hommes', '1986', '', NaT]
#  ********************
# ['16', '12494', 'DNF', 'Didier Metral', 'FR', 'Master 1 Hommes', '1979', '', NaT]
#  ********************
# ['19', '12497', 'DNF', 'Carlos Galvache Oliver', 'ES', 'Master 1 Hommes', '1974', '', NaT]
#  ********************
# ['21', '12499', 'DNF', 'Luciano Micheletti', 'IT', 'Master 3 Hommes', '1956', '', NaT]
#  ********************
# ['25', '12503', 'DNF', 'Valery Bertrand', 'BE', 'Master 1 Hommes', '1980', '', NaT]
#  ********************
# ['28', '12506', 'DNF', 'Martial Hebert', 'FR', 'Master 2 Hommes', '1971', '', NaT]
#  ********************
# ['30', '12508', 'DNF', 'Eric Ressencourt', 'FR', 'Master 1 Hommes', '1975', '', NaT]
#  ********************
# ['34', '12512', 'DNF', 'Olle Rõuk', 'EE', 'Master 1 Hommes', '1974', '', NaT]
#  ********************
# ['39', '12517', 'DNF', 'Osman Komurcu', 'GB', 'Master 1 Hommes', '1973', '', NaT]
#  ********************
# ['40', '12518', 'DNF', 'Franck Deconynck', 'FR', 'Master 2 Hommes', '1966', '', NaT]
#  ********************
# ['41', '12519', 'DNF', 'Stéphane Poiroux', 'FR', 'Master 1 Hommes', '1973', '', NaT]
#  ********************
# ['46', '12524', 'DNF', 'Alessandro Brioschi', 'IT', 'Seniors Hommes', '1985', '', NaT]
#  ********************
# ['49', '12528', 'DNF', 'Fabrice Gueriot', 'FR', 'Master 1 Hommes', '1973', '', NaT]
#  ********************
# ['50', '12529', 'DNF', 'Mark Thompson', 'GB', 'Master 2 Hommes', '1966', '', NaT]
#  ********************
# ['51', '12530', 'DNF', 'Ludovic Garitte', 'FR', 'Master 1 Hommes', '1975', '', NaT]
#  ********************
# ['53', '12532', 'DNF', 'Thierry Pecherand', 'FR', 'Master 1 Hommes', '1973', '', NaT]
#  ********************
# ['54', '12533', 'DNF', 'Joachim Lefevre', 'BE', 'Seniors Hommes', '1991', '', NaT]
#  ********************
# ['55', '12534', 'DNF', 'Sebastien Noblet', 'FR', 'Master 1 Hommes', '1974', '', NaT]
#  ********************
# ['57', '12536', 'DNF', 'Timo Vogel', 'DE', 'Master 1 Hommes', '1977', '', NaT]
#  ********************
# ['58', '12537', 'DNF', 'Michel Le Mercier', 'FR', 'Master 2 Hommes', '1969', '', NaT]
#  ********************
# ['63', '12542', 'DNF', 'William Chevy', 'FR', 'Seniors Hommes', '1986', '', NaT]
#  ********************
# ['64', '12543', 'DNF', 'Adrien Robert', 'FR', 'Seniors Hommes', '1989', '', NaT]
#  ********************
# ['66', '12545', 'DNF', 'Frank Benoit-Gonnin', 'FR', 'Master 1 Hommes', '1972', '', NaT]
#  ********************
# ['71', '12551', 'DNF', 'Renaud Mahévo', 'FR', 'Master 2 Hommes', '1965', '', NaT]
#  ********************
# ['74', '12555', 'DNF', 'Cedric Touny', 'FR', 'Seniors Hommes', '1989', '', NaT]
#  ********************
# ['76', '12557', 'DNF', 'Mickaël Garry', 'FR', 'Seniors Hommes', '1982', '', NaT]
#  ********************
# ['77', '12558', 'DNF', 'Gilbert Villien', 'FR', 'Master 3 Hommes', '1961', '', NaT]
#  ********************
# ['78', '12559', 'DNF', 'Mathieu Bazin', 'FR', 'Master 1 Hommes', '1977', '', NaT]
#  ********************
# ['81', '12562', 'DNF', 'Philippe Debadier', 'FR', 'Master 1 Hommes', '1978', '', NaT]
#  ********************
# ['87', '12569', 'DNF', 'Andrea Panicco', 'IT', 'Master 1 Hommes', '1973', '', NaT]
#  ********************
# ['96', '12579', 'DNF', 'Tom Weis', 'DE', 'Master 2 Hommes', '1967', '', NaT]
#  ********************
# ['98', '12582', 'DNF', 'Nicolas Sarthou', 'FR', 'Seniors Hommes', '1985', '', NaT]
#  ********************
# ['103', '12587', 'DNF', 'Jean-Luc Trullemans', 'BE', 'Master 1 Hommes', '1973', '', NaT]
#  ********************
# ['105', '12589', 'DNF', 'Robin Meyer', 'FR', 'Master 2 Hommes', '1963', '', NaT]
#  ********************
# ['108', '12592', 'DNF', 'Christophe Poncelet', 'FR', 'Master 2 Hommes', '1964', '', NaT]
#  ********************
# ['111', '12595', 'DNF', 'Dimitar Kyosev', 'BG', 'Master 1 Hommes', '1978', '', NaT]
#  ********************
# ['112', '12596', 'DNF', 'Danny Vandeput', 'BE', 'Master 2 Hommes', '1970', '', NaT]
#  ********************
# ['116', '12600', 'DNF', 'Olivier Pallavicini', 'FR', 'Master 1 Hommes', '1976', '', NaT]
#  ********************
# ['117', '12602', 'DNF', 'Duarte Felgueiras', 'FR', 'Master 1 Hommes', '1980', '', NaT]
#  ********************
# ['119', '12604', 'DNF', 'Frederic Doyen', 'FR', 'Master 2 Hommes', '1966', '', NaT]
#  ********************
# ['120', '12605', 'DNF', 'Philippe Ciapa', 'FR', 'Master 2 Hommes', '1963', '', NaT]
#  ********************
# ['128', '12614', 'DNF', 'Frank Buytaert', 'BE', 'Master 2 Hommes', '1971', '', NaT]
#  ********************
# ['131', '12617', 'DNF', 'Frédéric Rossier', 'CH', 'Master 2 Hommes', '1967', '', NaT]
#  ********************
# ['132', '12618', 'DNF', 'Urs Voegeli-Asisa', 'CH', 'Master 2 Hommes', '1964', '', NaT]
#  ********************
# ['133', '12619', 'DNF', 'Ivan Hunziker', 'CH', 'Seniors Hommes', '1983', '', NaT]
#  ********************
# ['139', '12625', 'DNF', 'Roland Bächli', 'CH', 'Master 1 Hommes', '1976', '', NaT]
#  ********************
# ['140', '12626', 'DNF', 'Felix Moser', 'CH', 'Master 2 Hommes', '1968', '', NaT]
#  ********************
# ['147', '12633', 'DNF', 'Hannes Tautscher', 'AT', 'Master 1 Hommes', '1972', '', NaT]
#  ********************
# ['154', '12640', 'DNF', 'Peter Tönz', 'CH', 'Seniors Hommes', '1984', '', NaT]
#  ********************
# ['158', '12645', 'DNF', 'Frédéric Duboux', 'CH', 'Master 2 Hommes', '1969', '', NaT]
#  ********************
# ['159', '12646', 'DNF', 'Roberto Flores-Briones', 'CL', 'Master 2 Hommes', '1971', '', NaT]
#  ********************
# ['160', '12647', 'DNF', 'Milan Milanovic', 'CH', 'Master 3 Hommes', '1960', '', NaT]
#  ********************
# ['161', '12648', 'DNF', 'Frédéric Martin', 'CH', 'Seniors Hommes', '1984', '', NaT]
#  ********************
# ['162', '12649', 'DNF', 'François Mach', 'CH', 'Master 3 Hommes', '1961', '', NaT]
#  ********************
# ['164', '12651', 'DNF', 'Christophe Moser', 'CH', 'Master 2 Hommes', '1971', '', NaT]
#  ********************
# ['167', '12654', 'DNF', 'Christian Besson', 'CH', 'Master 2 Hommes', '1966', '', NaT]
#  ********************
# ['175', '12663', 'DNF', 'Martin Spahr', 'CH', 'Master 2 Hommes', '1971', '', NaT]
#  ********************
# ['179', '12667', 'DNF', 'Joseph Beytrison', 'CH', 'Master 1 Hommes', '1973', '', NaT]
#  ********************
# ['180', '12668', 'DNF', 'Giles Ruck', 'GB', 'Master 2 Hommes', '1967', '', NaT]
#  ********************
# ['184', '12672', 'DNF', 'Antoni Martí Mases', 'ES', 'Master 2 Hommes', '1971', '', NaT]
#  ********************
# ['185', '12673', 'DNF', 'Alex Mases Xifrè', 'ES', 'Master 1 Hommes', '1975', '', NaT]
#  ********************
# ['190', '12678', 'DNF', 'Arno Lux', 'BE', 'Master 2 Hommes', '1966', '', NaT]
#  ********************
# ['191', '12679', 'DNF', 'Christophe Ernst', 'BE', 'Master 2 Hommes', '1970', '', NaT]
#  ********************
# ['195', '12683', 'DNF', 'Bertrand Penot', 'FR', 'Master 2 Hommes', '1970', '', NaT]
#  ********************
# ['202', '12690', 'DNF', 'Pi Cheng Shen', 'TW', 'Master 2 Hommes', '1968', '', NaT]
#  ********************
# ['206', '12694', 'DNF', 'Ville Maksimainen', 'FI', 'Master 1 Hommes', '1975', '', NaT]
#  ********************
# ['207', '12695', 'DNF', 'Carles Raimat Quintana', 'ES', 'Master 1 Hommes', '1972', '', NaT]
#  ********************
# ['208', '12696', 'DNF', 'Frédéric Bernard', 'BE', 'Master 2 Hommes', '1968', '', NaT]
#  ********************
# ['210', '12698', 'DNF', 'Eric Perrin', 'BE', 'Master 2 Hommes', '1969', '', NaT]
#  ********************
# ['214', '12703', 'DNF', 'Johannes Schnitzer', 'CH', 'Seniors Hommes', '1982', '', NaT]
#  ********************
# ['216', '12705', 'DNF', 'Massimo Gessaga', 'IT', 'Master 3 Hommes', '1961', '', NaT]
#  ********************
# ['223', '12712', 'DNF', 'Basile Megali', 'FR', 'Master 3 Hommes', '1955', '', NaT]
#  ********************
# ['226', '13356', 'DNF', 'Van Thinh Vu', 'VN', 'Master 1 Hommes', '1973', '', NaT]
#  ********************
# ['229', '13365', 'DNF', 'Cristiano Gross', 'IT', 'Master 1 Hommes', '1974', '', NaT]
#  ********************
# ['232', '13370', 'DNF', 'Fabrice Voillaume', 'FR', 'Master 2 Hommes', '1968', '', NaT]
#  ********************
# ['239', '13386', 'DNF', 'Pascal Mauduit', 'FR', 'Master 2 Hommes', '1968', '', NaT]
#  ********************
# ['242', '13393', 'DNF', 'Aleš Bajc', 'SI', 'Master 2 Hommes', '1971', '', NaT]
#  ********************
# ['244', '13396', 'DNF', 'Marcel Haener', 'CH', 'Master 2 Hommes', '1965', '', NaT]
#  ********************
# ['249', '13405', 'DNF', 'Bruno Delaval', 'FR', 'Master 1 Hommes', '1972', '', NaT]
#  ********************
# ['251', '13407', 'DNF', 'James Cheesman', 'GB', 'Master 2 Hommes', '1971', '', NaT]
#  ********************
# ['257', '13425', 'DNF', 'Alban Venneugues', 'FR', 'Master 1 Hommes', '1979', '', NaT]
#  ********************
# ['261', '13433', 'DNF', 'Samuel Nardon', 'FR', 'Master 1 Hommes', '1973', '', NaT]
#  ********************
# ['266', '13459', 'DNF', 'Bertrand De Longvilliers', 'FR', 'Master 3 Hommes', '1956', '', NaT]
#  ********************
# ['268', '13462', 'DNF', 'Roman Bürgler', 'CH', 'Master 1 Hommes', '1973', '', NaT]
#  ********************
# ['271', '13466', 'DNF', 'Philippe Bessy', 'FR', 'Master 2 Hommes', '1965', '', NaT]
#  ********************
# ['274', '13472', 'DNF', 'René Zbinden', 'CH', 'Master 1 Hommes', '1972', '', NaT]
#  ********************
# ['279', '13485', 'DNF', 'Philippe Gimbert', 'FR', 'Master 3 Hommes', '1956', '', NaT]
#  ********************
# ['283', '13496', 'DNF', 'Florian Dufour', 'BE', 'Seniors Hommes', '1989', '', NaT]
#  ********************
# ['288', '13518', 'DNF', 'Jorge Galve', 'ES', 'Seniors Hommes', '1985', '', NaT]
#  ********************
# ['289', '13521', 'DNF', 'Vincent Lecarpentier', 'FR', 'Master 2 Hommes', '1971', '', NaT]
#  ********************
# ['294', '13540', 'DNF', 'Christophe Brebant', 'FR', 'Master 3 Hommes', '1960', '', NaT]
#  ********************
# ['295', '13545', 'DNF', 'Tony Das Neves', 'FR', 'Master 1 Hommes', '1972', '', NaT]
#  ********************
# ['296', '13548', 'DNF', 'Mathis Marugg', 'CH', 'Master 2 Hommes', '1970', '', NaT]
#  ********************
# ['297', '13558', 'DNF', 'Laurent Teurnier', 'FR', 'Master 2 Hommes', '1971', '', NaT]
#  ********************
# ['299', '13577', 'DNF', 'Antoine Piatti', 'CH', 'Seniors Hommes', '1986', '', NaT]
#  ********************
# ['302', '13594', 'DNF', 'Olivier Delait', 'BE', 'Master 2 Hommes', '1967', '', NaT]
#  ********************
# ['304', '13605', 'DNF', 'Clément Carrier', 'FR', 'Seniors Hommes', '1992', '', NaT]
#  ********************
# ['308', '13620', 'DNF', 'Wolfgang Lohr', 'DE', 'Master 2 Hommes', '1967', '', NaT]
#  ********************
# ['309', '13621', 'DNF', 'Adrien Galan', 'FR', 'Seniors Hommes', '1983', '', NaT]
#  ********************
# ['310', '13624', 'DNF', 'Mordehai Pekar', 'IL', 'Master 3 Hommes', '1960', '', NaT]
#  ********************
# ['312', '13628', 'DNF', 'Philippe Roberts', 'GB', 'Master 2 Hommes', '1969', '', NaT]
#  ********************
# ['314', '13646', 'DNF', 'Pierre Griffaton', 'FR', 'Master 1 Hommes', '1972', '', NaT]
#  ********************
# ['320', '13688', 'DNF', 'Ludovic Champion', 'FR', 'Master 1 Hommes', '1972', '', NaT]
#  ********************
# ['321', '13700', 'DNF', 'Brice Peninon', 'FR', 'Master 1 Hommes', '1978', '', NaT]
#  ********************
# ['322', '13709', 'DNF', 'Apostolos Teknetzis', 'FR', 'Master 1 Hommes', '1981', '', NaT]
#  ********************
# ['324', '13715', 'DNF', 'Umberto Chiodi', 'IT', 'Seniors Hommes', '1990', '', NaT]
#  ********************
# ['325', '13716', 'DNF', 'Gregorio Aiello', 'IT', 'Seniors Hommes', '1991', '', NaT]
#  ********************
# ['328', '13742', 'DNF', 'Thierry Delmotte', 'FR', 'Master 2 Hommes', '1963', '', NaT]
#  ********************
# ['330', '13745', 'DNF', 'Fred Werneck', 'CH', 'Master 1 Hommes', '1979', '', NaT]
#  ********************
# ['332', '13769', 'DNF', 'Paolo Girolami', 'IE', 'Master 1 Hommes', '1972', '', NaT]
#  ********************
# ['333', '13774', 'DNF', 'Pierre Gagniere', 'FR', 'Master 3 Hommes', '1953', '', NaT]
#  ********************
# ['334', '13779', 'DNF', 'Josep Sanglas Ayats', 'ES', 'Master 3 Hommes', '1957', '', NaT]
#  ********************
# ['337', '13785', 'DNF', 'Jean-Pierre Couzin', 'FR', 'Master 3 Hommes', '1959', '', NaT]
#  ********************
# ['339', '13799', 'DNF', 'Claude Schneider', 'FR', 'Master 3 Hommes', '1960', '', NaT]
#  ********************
# ['340', '13813', 'DNF', 'Jürgen Hugenschmidt', 'DE', 'Master 3 Hommes', '1956', '', NaT]
#  ********************
# ['348', '13899', 'DNF', 'Shane Bryant', 'US', 'Master 1 Hommes', '1978', '', NaT]
#  ********************
# ['349', '13908', 'DNF', 'Xavier Armange', 'FR', 'Master 1 Hommes', '1973', '', NaT]
#  ********************
# ['351', '13953', 'DNF', 'Pierre Masset', 'BE', 'Seniors Hommes', '1994', '', NaT]
#  ********************
# ['358', '13994', 'DNF', 'Matthias Kälberer', 'DE', 'Seniors Hommes', '1984', '', NaT]
#  ********************
# ['359', '13999', 'DNF', 'Michel Lonfat', 'CH', 'Master 2 Hommes', '1968', '', NaT]
#  ********************
# ['361', '14008', 'DNF', 'Dimitrios Ziamparas', 'GR', 'Master 2 Hommes', '1969', '', NaT]
#  ********************
# ['365', '14088', 'DNF', 'Jean Pierre Blachier', 'FR', 'Master 2 Hommes', '1970', '', NaT]
#  ********************
# ['372', '14316', 'DNF', 'Sébastien Jaques', 'CH', 'Seniors Hommes', '1989', '', NaT]
#  ********************
# ['374', '14356', 'DNF', 'Angel Kanchev', 'BG', 'Master 1 Hommes', '1976', '', NaT]
#  ********************
# ['378', '14388', 'DNF', 'Fransesc Ferrer', 'IT', 'Master 1 Hommes', '1973', '', NaT]
#  ********************
# ['380', '13480', 'DNF', 'Paweł Potempski', 'PL', 'Master 1 Hommes', '1977', '', NaT]
#  ********************
# ['382', '13863', 'DNF', 'Jiří Hálek', 'CZ', 'Seniors Hommes', '1986', '', NaT]
#  ********************
# [293]
# Fetching from: https://my4.raceresult.com/161079/RRPublish/data/list?key=374250657b42ce1a7a8e1a4a3311786d&listname=Result%20Lists%7CProv.%20Gender%20Results%20360&page=results&contest=1&r=group&name=%231_Female&f=
# ['5', '12490', '1.', 'Anita Lehmann', 'CH', 'Master 1 Femmes', '1980', '', Timedelta('4 days 09:06:23')]
#  ********************
# ['7', '14420', '2.', 'Denise Zimmermann', 'CH', 'Master 1 Femmes', '1975', '', Timedelta('4 days 17:44:25')]
#  ********************
# ['102', '12586', '3.', 'Alessandra Olivi', 'IT', 'Seniors Femmes', '1991', '', Timedelta('4 days 20:03:19')]
#  ********************
# ['367', '14120', '4.', 'Katja Fink', 'CH', 'Master 1 Femmes', '1975', '', Timedelta('4 days 20:36:47')]
#  ********************
# ['91', '12573', '5.', 'Héloïse Aeberli', 'FR', 'Seniors Femmes', '1987', '', Timedelta('5 days 00:23:27')]
#  ********************
# ['376', '14379', '6.', 'Aneta Ralcheva', 'BG', 'Master 2 Femmes', '1967', '', Timedelta('5 days 04:13:29')]
#  ********************
# ['235', '13525', '7.', 'Sophie Bouquet', 'FR', 'Master 2 Femmes', '1969', '', Timedelta('5 days 04:59:35')]
#  ********************
# ['125', '12611', '8.', 'Manon Clerc', 'FR', 'Seniors Femmes', '1996', '', Timedelta('5 days 07:10:34')]
#  ********************
# ['148', '12634', '9.', 'Catherine Rion', 'CH', 'Master 1 Femmes', '1978', '', Timedelta('5 days 10:27:52')]
#  ********************
# ['156', '12643', '10.', 'Cornelia Hauser-Ruckli', 'CH', 'Master 2 Femmes', '1968', '', Timedelta('5 days 10:49:21')]
#  ********************
# ['56', '12535', '11.', 'Maria Ilaria Fossati', 'IT', 'Master 1 Femmes', '1972', '', Timedelta('5 days 20:50:11')]
#  ********************
# ['170', '12658', '12.', 'Xiabingqing Wu', 'CN', 'Seniors Femmes', '1990', '', Timedelta('6 days 01:54:48')]
#  ********************
# ['362', '14031', '13.', 'Mònica Guilera', 'ES', 'Master 1 Femmes', '1979', '', Timedelta('6 days 04:10:30')]
#  ********************
# ['169', '12656', '14.', 'Annina Michel', 'CH', 'Seniors Femmes', '1989', '', Timedelta('6 days 04:35:35')]
#  ********************
# ['43', '12521', '15.', 'Vanessa Prouteau', 'FR', 'Seniors Femmes', '1984', '', Timedelta('6 days 05:24:11')]
#  ********************
# ['129', '12615', '16.', 'Petra De Bruin', 'NL', 'Master 1 Femmes', '1979', '', Timedelta('6 days 05:52:37')]
#  ********************
# ['240', '13387', '17.', 'Emmanuelle Jaeglin', 'FR', 'Master 2 Femmes', '1969', '', Timedelta('6 days 06:32:28')]
#  ********************
# ['24', '12502', '18.', 'Ewa Trzetrzelewska-Lalik', 'PL', 'Master 1 Femmes', '1975', '', Timedelta('6 days 08:07:36')]
#  ********************
# ['42', '12520', 'DNF', 'Cécile Poiroux', 'FR', 'Master 1 Femmes', '1973', '', NaT]
#  ********************
# ['106', '12590', 'DNF', 'Anna-Isabelle Laboube', 'FR', 'Master 1 Femmes', '1972', '', NaT]
#  ********************
# ['114', '12598', 'DNF', 'Virginie Duterme', 'FR', 'Master 1 Femmes', '1973', '', NaT]
#  ********************
# ['153', '12639', 'DNF', 'Olga Fikarova Zrzavecka', 'CZ', 'Master 1 Femmes', '1977', '', NaT]
#  ********************
# ['171', '12659', 'DNF', 'Julie Rapenne', 'FR', 'Master 1 Femmes', '1980', '', NaT]
#  ********************
# ['174', '12662', 'DNF', 'Susan Müller', 'DE', 'Master 1 Femmes', '1974', '', NaT]
#  ********************
# ['176', '12664', 'DNF', 'Stéphanie Perriard', 'CH', 'Seniors Femmes', '1985', '', NaT]
#  ********************
# ['178', '12666', 'DNF', 'Satu Iho', 'FI', 'Seniors Femmes', '1984', '', NaT]
#  ********************
# ['316', '13652', 'DNF', 'Myrianna De Icco', 'CH', 'Seniors Femmes', '1986', '', NaT]
#  ********************
# ['335', '13781', 'DNF', 'Berengere Bastiani', 'FR', 'Master 2 Femmes', '1969', '', NaT]
#  ********************
# ['354', '13962', 'DNF', 'Lenka Berrouche', 'CZ', 'Master 1 Femmes', '1980', '', NaT]
#  ********************
# [29]

# %%
SP_dem_df =  pd.DataFrame(runner_list, columns = ['Bib', 'ID', 'Status', 'Name', 
                               'Nationality',
                               'Age Category',
                                'Birth Year', 'Club', 'Duration'])   
SP_dem_df['Status'] = np.where(SP_dem_df['Status'] == 'DNF', 'DNF', 'Finished')
SP_dem_df['Year'] = year
SP_dem_df['Race'] = 'SP360'

SP_dem_df.loc[SP_dem_df['Age Category'].str.contains('Hommes'), 'Gender'] = 'M'
SP_dem_df.loc[SP_dem_df['Age Category'].str.contains('Femmes'), 'Gender'] = 'F'
SP_dem_df['Age Category'] = SP_dem_df['Age Category'].str.replace(' Femmes', '')
SP_dem_df['Age Category'] = SP_dem_df['Age Category'].str.replace(' Hommes', '')

SP_dem_df['PK'] = SP_dem_df['Race'] +'_' + SP_dem_df['Year'] +'_' + SP_dem_df['Bib']    

SP_dem_df = SP_dem_df[[
     'Bib', 'ID','Name','Status', 'Nationality', 'Gender', 
    'Birth Year', 'Duration', 'Year', 'Race', 'PK']]

SP_dem_df.head()
# Out:
#    Bib     ID              Name    Status Nationality Gender Birth Year  \
# 0    2  14362      Peter Kienzl  Finished          IT      M       1975
# 1    4  12489    Michael Nançoz  Finished          CH      M       1988
# 2  369  14181  Hendrik Spoering  Finished          DE      M       1990
# 3   36  12514       Nicolas Bie  Finished          FR      M       1977
# 4   13  14065        Lucas Papi  Finished          IT      M       1980
#
#          Duration  Year   Race              PK
# 0 3 days 14:34:28  2021  SP360    SP360_2021_2
# 1 3 days 21:51:22  2021  SP360    SP360_2021_4
# 2 4 days 03:18:46  2021  SP360  SP360_2021_369
# 3 4 days 04:37:23  2021  SP360   SP360_2021_36
# 4 4 days 05:21:47  2021  SP360   SP360_2021_13

# %%
SP_dem_df.to_excel(f'Data/SwissPeaks360_{year}_DEM.xlsx', index=False)

# %%
SP_dem_df[SP_dem_df['Status'] == 'DNF']
# Out:
#      Bib     ID                    Name Status Nationality Gender Birth Year  \
# 164    3  13380           Serge Lattion    DNF          CH      M       1973
# 165    6  14408      Joachim Pellissier    DNF          CH      M       1978
# 166   10  14488            Jack B Liver    DNF          CH      M       1986
# 167   16  12494           Didier Metral    DNF          FR      M       1979
# 168   19  12497  Carlos Galvache Oliver    DNF          ES      M       1974
# ..   ...    ...                     ...    ...         ...    ...        ...
# 317  176  12664      Stéphanie Perriard    DNF          CH      F       1985
# 318  178  12666                Satu Iho    DNF          FI      F       1984
# 319  316  13652        Myrianna De Icco    DNF          CH      F       1986
# 320  335  13781      Berengere Bastiani    DNF          FR      F       1969
# 321  354  13962         Lenka Berrouche    DNF          CZ      F       1980
#
#     Duration  Year   Race              PK
# 164      NaT  2021  SP360    SP360_2021_3
# 165      NaT  2021  SP360    SP360_2021_6
# 166      NaT  2021  SP360   SP360_2021_10
# 167      NaT  2021  SP360   SP360_2021_16
# 168      NaT  2021  SP360   SP360_2021_19
# ..       ...   ...    ...             ...
# 317      NaT  2021  SP360  SP360_2021_176
# 318      NaT  2021  SP360  SP360_2021_178
# 319      NaT  2021  SP360  SP360_2021_316
# 320      NaT  2021  SP360  SP360_2021_335
# 321      NaT  2021  SP360  SP360_2021_354
#
# [140 rows x 11 columns]

# %% [markdown]
# ### Using bib column to extract station

# %%
list(SP_dem_df['ID'].unique())[:1]
# Out:
# ['14362']

# %%
station_list = []
failed_to_fetch= []
n=0
# Loop through the unique bibs in the DataFrame
for unique_id in list(SP_dem_df['ID'].unique()):  # Limit to just one bib for testing
    n = n+1
    print(n, ' - ', unique_id)
    
    # URL of the JSON file
    url = f'https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid={unique_id}'
    print(url)

    # Send a GET request to fetch the JSON data
    response = requests.get(url)

    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        # Parse the JSON data
        data = response.json()
        stations = data['Splits']
        
        # Loop through the stations
        for station in stations:
            station_name = station['Name']
            exists = station['Exists']
            
            # Helper function to format durations safely
            def get_formatted_duration(key):
                duration = station.get(key)
                if duration:
                    return f"{duration.split(':')[0]} days {':'.join(duration.split(':')[1:])}"
                return np.nan

            formatted_gun = get_formatted_duration('Gun')
            formatted_chip = get_formatted_duration('Chip')
            formatted_sector = get_formatted_duration('Sector')

            # Store the extracted info in the station list
            extracted_info = [unique_id, station_name, exists,
                              formatted_gun, 
                              formatted_chip,
                              formatted_sector]
            station_list.append(extracted_info)
            
    else:
        print(f"Failed to fetch data for {unique_id}. Status code: {response.status_code}")
        failed_to_fetch.append(unique_id)
        
    
    #### So we dont get blocked!!!!
    delay_seconds = random.randint(5,10)
    print('Delay before calling the server again: ', delay_seconds)
    print('*'*20)
    time.sleep(delay_seconds)
# Out:
# 1  -  14362
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=14362
# Delay before calling the server again:  10
# ********************
# 2  -  12489
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12489
# Delay before calling the server again:  6
# ********************
# 3  -  14181
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=14181
# Delay before calling the server again:  8
# ********************
# 4  -  12514
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12514
# Delay before calling the server again:  7
# ********************
# 5  -  14065
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=14065
# Delay before calling the server again:  8
# ********************
# 6  -  14366
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=14366
# Delay before calling the server again:  7
# ********************
# 7  -  13522
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13522
# Delay before calling the server again:  5
# ********************
# 8  -  12591
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12591
# Delay before calling the server again:  6
# ********************
# 9  -  13461
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13461
# Delay before calling the server again:  10
# ********************
# 10  -  13657
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13657
# Delay before calling the server again:  6
# ********************
# 11  -  13455
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13455
# Delay before calling the server again:  6
# ********************
# 12  -  12584
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12584
# Delay before calling the server again:  9
# ********************
# 13  -  14204
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=14204
# Delay before calling the server again:  10
# ********************
# 14  -  13491
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13491
# Delay before calling the server again:  5
# ********************
# 15  -  13585
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13585
# Delay before calling the server again:  8
# ********************
# 16  -  13363
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13363
# Delay before calling the server again:  7
# ********************
# 17  -  13465
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13465
# Delay before calling the server again:  10
# ********************
# 18  -  12513
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12513
# Delay before calling the server again:  10
# ********************
# 19  -  14336
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=14336
# Delay before calling the server again:  8
# ********************
# 20  -  12548
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12548
# Delay before calling the server again:  5
# ********************
# 21  -  13721
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13721
# Delay before calling the server again:  5
# ********************
# 22  -  13604
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13604
# Delay before calling the server again:  9
# ********************
# 23  -  13446
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13446
# Delay before calling the server again:  7
# ********************
# 24  -  12661
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12661
# Delay before calling the server again:  7
# ********************
# 25  -  12713
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12713
# Delay before calling the server again:  8
# ********************
# 26  -  12538
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12538
# Delay before calling the server again:  7
# ********************
# 27  -  13406
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13406
# Delay before calling the server again:  9
# ********************
# 28  -  13456
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13456
# Delay before calling the server again:  5
# ********************
# 29  -  12685
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12685
# Delay before calling the server again:  7
# ********************
# 30  -  12498
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12498
# Delay before calling the server again:  7
# ********************
# 31  -  12539
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12539
# Delay before calling the server again:  10
# ********************
# 32  -  14360
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=14360
# Delay before calling the server again:  7
# ********************
# 33  -  12563
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12563
# Delay before calling the server again:  8
# ********************
# 34  -  13420
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13420
# Delay before calling the server again:  6
# ********************
# 35  -  12623
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12623
# Delay before calling the server again:  7
# ********************
# 36  -  12714
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12714
# Delay before calling the server again:  9
# ********************
# 37  -  13825
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13825
# Delay before calling the server again:  10
# ********************
# 38  -  12570
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12570
# Delay before calling the server again:  9
# ********************
# 39  -  12556
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12556
# Delay before calling the server again:  5
# ********************
# 40  -  12522
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12522
# Delay before calling the server again:  10
# ********************
# 41  -  13888
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13888
# Delay before calling the server again:  7
# ********************
# 42  -  12711
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12711
# Delay before calling the server again:  7
# ********************
# 43  -  14260
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=14260
# Delay before calling the server again:  10
# ********************
# 44  -  13438
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13438
# Delay before calling the server again:  6
# ********************
# 45  -  12495
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12495
# Delay before calling the server again:  9
# ********************
# 46  -  13512
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13512
# Delay before calling the server again:  6
# ********************
# 47  -  12708
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12708
# Delay before calling the server again:  6
# ********************
# 48  -  12546
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12546
# Delay before calling the server again:  8
# ********************
# 49  -  13362
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13362
# Delay before calling the server again:  8
# ********************
# 50  -  12636
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12636
# Delay before calling the server again:  6
# ********************
# 51  -  12531
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12531
# Delay before calling the server again:  10
# ********************
# 52  -  12549
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12549
# Delay before calling the server again:  6
# ********************
# 53  -  13571
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13571
# Delay before calling the server again:  7
# ********************
# 54  -  12631
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12631
# Delay before calling the server again:  9
# ********************
# 55  -  13674
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13674
# Delay before calling the server again:  8
# ********************
# 56  -  12684
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12684
# Delay before calling the server again:  9
# ********************
# 57  -  12606
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12606
# Delay before calling the server again:  9
# ********************
# 58  -  12612
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12612
# Delay before calling the server again:  8
# ********************
# 59  -  12674
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12674
# Delay before calling the server again:  5
# ********************
# 60  -  12608
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12608
# Delay before calling the server again:  6
# ********************
# 61  -  13402
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13402
# Delay before calling the server again:  7
# ********************
# 62  -  12516
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12516
# Delay before calling the server again:  10
# ********************
# 63  -  13414
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13414
# Delay before calling the server again:  7
# ********************
# 64  -  13432
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13432
# Delay before calling the server again:  7
# ********************
# 65  -  12621
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12621
# Delay before calling the server again:  5
# ********************
# 66  -  12509
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12509
# Delay before calling the server again:  8
# ********************
# 67  -  12613
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12613
# Delay before calling the server again:  6
# ********************
# 68  -  12583
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12583
# Delay before calling the server again:  8
# ********************
# 69  -  12572
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12572
# Delay before calling the server again:  8
# ********************
# 70  -  12635
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12635
# Delay before calling the server again:  8
# ********************
# 71  -  13818
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13818
# Delay before calling the server again:  7
# ********************
# 72  -  13676
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13676
# Delay before calling the server again:  10
# ********************
# 73  -  12544
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12544
# Delay before calling the server again:  5
# ********************
# 74  -  13395
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13395
# Delay before calling the server again:  5
# ********************
# 75  -  12650
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12650
# Delay before calling the server again:  6
# ********************
# 76  -  12575
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12575
# Delay before calling the server again:  5
# ********************
# 77  -  12568
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12568
# Delay before calling the server again:  9
# ********************
# 78  -  12704
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12704
# Delay before calling the server again:  7
# ********************
# 79  -  12700
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12700
# Delay before calling the server again:  6
# ********************
# 80  -  12624
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12624
# Delay before calling the server again:  7
# ********************
# 81  -  13833
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13833
# Delay before calling the server again:  7
# ********************
# 82  -  12702
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12702
# Delay before calling the server again:  8
# ********************
# 83  -  12588
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12588
# Delay before calling the server again:  8
# ********************
# 84  -  12680
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12680
# Delay before calling the server again:  7
# ********************
# 85  -  12599
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12599
# Delay before calling the server again:  9
# ********************
# 86  -  12597
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12597
# Delay before calling the server again:  9
# ********************
# 87  -  12671
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12671
# Delay before calling the server again:  9
# ********************
# 88  -  12501
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12501
# Delay before calling the server again:  5
# ********************
# 89  -  13403
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13403
# Delay before calling the server again:  5
# ********************
# 90  -  13398
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13398
# Delay before calling the server again:  7
# ********************
# 91  -  13464
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13464
# Delay before calling the server again:  6
# ********************
# 92  -  13965
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13965
# Delay before calling the server again:  7
# ********************
# 93  -  13471
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13471
# Delay before calling the server again:  8
# ********************
# 94  -  12653
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12653
# Delay before calling the server again:  5
# ********************
# 95  -  13606
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13606
# Delay before calling the server again:  6
# ********************
# 96  -  12620
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12620
# Delay before calling the server again:  10
# ********************
# 97  -  12560
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12560
# Delay before calling the server again:  8
# ********************
# 98  -  12515
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12515
# Delay before calling the server again:  6
# ********************
# 99  -  13413
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13413
# Delay before calling the server again:  10
# ********************
# 100  -  12676
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12676
# Delay before calling the server again:  9
# ********************
# 101  -  12677
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12677
# Delay before calling the server again:  10
# ********************
# 102  -  14068
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=14068
# Delay before calling the server again:  7
# ********************
# 103  -  12607
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12607
# Delay before calling the server again:  5
# ********************
# 104  -  12574
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12574
# Delay before calling the server again:  7
# ********************
# 105  -  12638
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12638
# Delay before calling the server again:  5
# ********************
# 106  -  13449
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13449
# Delay before calling the server again:  8
# ********************
# 107  -  13768
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13768
# Delay before calling the server again:  7
# ********************
# 108  -  13431
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13431
# Delay before calling the server again:  10
# ********************
# 109  -  12504
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12504
# Delay before calling the server again:  6
# ********************
# 110  -  12565
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12565
# Delay before calling the server again:  7
# ********************
# 111  -  13489
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13489
# Delay before calling the server again:  6
# ********************
# 112  -  13486
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13486
# Delay before calling the server again:  10
# ********************
# 113  -  12642
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12642
# Delay before calling the server again:  5
# ********************
# 114  -  14005
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=14005
# Delay before calling the server again:  7
# ********************
# 115  -  12644
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12644
# Delay before calling the server again:  8
# ********************
# 116  -  14367
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=14367
# Delay before calling the server again:  5
# ********************
# 117  -  12710
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12710
# Delay before calling the server again:  6
# ********************
# 118  -  12697
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12697
# Delay before calling the server again:  5
# ********************
# 119  -  13854
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13854
# Delay before calling the server again:  9
# ********************
# 120  -  13993
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13993
# Delay before calling the server again:  5
# ********************
# 121  -  13382
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13382
# Delay before calling the server again:  7
# ********************
# 122  -  13383
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13383
# Delay before calling the server again:  6
# ********************
# 123  -  13473
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13473
# Delay before calling the server again:  8
# ********************
# 124  -  12709
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12709
# Delay before calling the server again:  9
# ********************
# 125  -  13647
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13647
# Delay before calling the server again:  6
# ********************
# 126  -  13735
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13735
# Delay before calling the server again:  7
# ********************
# 127  -  12561
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12561
# Delay before calling the server again:  9
# ********************
# 128  -  12610
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12610
# Delay before calling the server again:  7
# ********************
# 129  -  12496
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12496
# Delay before calling the server again:  10
# ********************
# 130  -  12706
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12706
# Delay before calling the server again:  6
# ********************
# 131  -  12523
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12523
# Delay before calling the server again:  5
# ********************
# 132  -  12655
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12655
# Delay before calling the server again:  10
# ********************
# 133  -  13611
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13611
# Delay before calling the server again:  5
# ********************
# 134  -  12492
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12492
# Delay before calling the server again:  5
# ********************
# 135  -  12630
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12630
# Delay before calling the server again:  10
# ********************
# 136  -  12505
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12505
# Delay before calling the server again:  10
# ********************
# 137  -  12603
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12603
# Delay before calling the server again:  5
# ********************
# 138  -  13527
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13527
# Delay before calling the server again:  9
# ********************
# 139  -  13409
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13409
# Delay before calling the server again:  6
# ********************
# 140  -  12682
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12682
# Delay before calling the server again:  10
# ********************
# 141  -  12541
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12541
# Delay before calling the server again:  7
# ********************
# 142  -  12554
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12554
# Delay before calling the server again:  8
# ********************
# 143  -  13954
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13954
# Delay before calling the server again:  6
# ********************
# 144  -  13411
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13411
# Delay before calling the server again:  5
# ********************
# 145  -  12627
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12627
# Delay before calling the server again:  9
# ********************
# 146  -  13426
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13426
# Delay before calling the server again:  8
# ********************
# 147  -  13626
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13626
# Delay before calling the server again:  10
# ********************
# 148  -  12629
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12629
# Delay before calling the server again:  9
# ********************
# 149  -  13885
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13885
# Delay before calling the server again:  5
# ********************
# 150  -  12632
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12632
# Delay before calling the server again:  10
# ********************
# 151  -  13483
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13483
# Delay before calling the server again:  6
# ********************
# 152  -  13498
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13498
# Delay before calling the server again:  8
# ********************
# 153  -  13384
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13384
# Delay before calling the server again:  5
# ********************
# 154  -  13982
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13982
# Delay before calling the server again:  5
# ********************
# 155  -  13938
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13938
# Delay before calling the server again:  8
# ********************
# 156  -  13484
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13484
# Delay before calling the server again:  5
# ********************
# 157  -  13529
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13529
# Delay before calling the server again:  7
# ********************
# 158  -  13379
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13379
# Delay before calling the server again:  5
# ********************
# 159  -  13488
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13488
# Delay before calling the server again:  7
# ********************
# 160  -  14153
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=14153
# Delay before calling the server again:  10
# ********************
# 161  -  13712
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13712
# Delay before calling the server again:  6
# ********************
# 162  -  12500
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12500
# Delay before calling the server again:  7
# ********************
# 163  -  12581
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12581
# Delay before calling the server again:  8
# ********************
# 164  -  14063
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=14063
# Delay before calling the server again:  8
# ********************
# 165  -  13380
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13380
# Delay before calling the server again:  9
# ********************
# 166  -  14408
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=14408
# Delay before calling the server again:  6
# ********************
# 167  -  14488
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=14488
# Delay before calling the server again:  9
# ********************
# 168  -  12494
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12494
# Delay before calling the server again:  9
# ********************
# 169  -  12497
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12497
# Delay before calling the server again:  8
# ********************
# 170  -  12499
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12499
# Delay before calling the server again:  9
# ********************
# 171  -  12503
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12503
# Delay before calling the server again:  9
# ********************
# 172  -  12506
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12506
# Delay before calling the server again:  8
# ********************
# 173  -  12508
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12508
# Delay before calling the server again:  9
# ********************
# 174  -  12512
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12512
# Delay before calling the server again:  8
# ********************
# 175  -  12517
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12517
# Delay before calling the server again:  6
# ********************
# 176  -  12518
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12518
# Delay before calling the server again:  9
# ********************
# 177  -  12519
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12519
# Delay before calling the server again:  9
# ********************
# 178  -  12524
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12524
# Delay before calling the server again:  6
# ********************
# 179  -  12528
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12528
# Delay before calling the server again:  7
# ********************
# 180  -  12529
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12529
# Delay before calling the server again:  10
# ********************
# 181  -  12530
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12530
# Delay before calling the server again:  9
# ********************
# 182  -  12532
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12532
# Delay before calling the server again:  8
# ********************
# 183  -  12533
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12533
# Delay before calling the server again:  10
# ********************
# 184  -  12534
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12534
# Delay before calling the server again:  6
# ********************
# 185  -  12536
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12536
# Delay before calling the server again:  8
# ********************
# 186  -  12537
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12537
# Delay before calling the server again:  10
# ********************
# 187  -  12542
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12542
# Delay before calling the server again:  7
# ********************
# 188  -  12543
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12543
# Delay before calling the server again:  9
# ********************
# 189  -  12545
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12545
# Delay before calling the server again:  5
# ********************
# 190  -  12551
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12551
# Delay before calling the server again:  6
# ********************
# 191  -  12555
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12555
# Delay before calling the server again:  8
# ********************
# 192  -  12557
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12557
# Delay before calling the server again:  6
# ********************
# 193  -  12558
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12558
# Delay before calling the server again:  9
# ********************
# 194  -  12559
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12559
# Delay before calling the server again:  9
# ********************
# 195  -  12562
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12562
# Delay before calling the server again:  6
# ********************
# 196  -  12569
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12569
# Delay before calling the server again:  5
# ********************
# 197  -  12579
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12579
# Delay before calling the server again:  7
# ********************
# 198  -  12582
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12582
# Delay before calling the server again:  10
# ********************
# 199  -  12587
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12587
# Delay before calling the server again:  8
# ********************
# 200  -  12589
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12589
# Delay before calling the server again:  5
# ********************
# 201  -  12592
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12592
# Delay before calling the server again:  10
# ********************
# 202  -  12595
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12595
# Delay before calling the server again:  8
# ********************
# 203  -  12596
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12596
# Delay before calling the server again:  10
# ********************
# 204  -  12600
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12600
# Delay before calling the server again:  9
# ********************
# 205  -  12602
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12602
# Delay before calling the server again:  5
# ********************
# 206  -  12604
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12604
# Delay before calling the server again:  8
# ********************
# 207  -  12605
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12605
# Delay before calling the server again:  8
# ********************
# 208  -  12614
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12614
# Delay before calling the server again:  8
# ********************
# 209  -  12617
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12617
# Delay before calling the server again:  6
# ********************
# 210  -  12618
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12618
# Delay before calling the server again:  8
# ********************
# 211  -  12619
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12619
# Delay before calling the server again:  6
# ********************
# 212  -  12625
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12625
# Delay before calling the server again:  10
# ********************
# 213  -  12626
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12626
# Delay before calling the server again:  7
# ********************
# 214  -  12633
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12633
# Delay before calling the server again:  6
# ********************
# 215  -  12640
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12640
# Delay before calling the server again:  10
# ********************
# 216  -  12645
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12645
# Delay before calling the server again:  6
# ********************
# 217  -  12646
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12646
# Delay before calling the server again:  5
# ********************
# 218  -  12647
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12647
# Delay before calling the server again:  6
# ********************
# 219  -  12648
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12648
# Delay before calling the server again:  5
# ********************
# 220  -  12649
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12649
# Delay before calling the server again:  5
# ********************
# 221  -  12651
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12651
# Delay before calling the server again:  9
# ********************
# 222  -  12654
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12654
# Delay before calling the server again:  9
# ********************
# 223  -  12663
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12663
# Delay before calling the server again:  6
# ********************
# 224  -  12667
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12667
# Delay before calling the server again:  10
# ********************
# 225  -  12668
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12668
# Delay before calling the server again:  5
# ********************
# 226  -  12672
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12672
# Delay before calling the server again:  6
# ********************
# 227  -  12673
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12673
# Delay before calling the server again:  10
# ********************
# 228  -  12678
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12678
# Delay before calling the server again:  6
# ********************
# 229  -  12679
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12679
# Delay before calling the server again:  6
# ********************
# 230  -  12683
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12683
# Delay before calling the server again:  10
# ********************
# 231  -  12690
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12690
# Delay before calling the server again:  7
# ********************
# 232  -  12694
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12694
# Delay before calling the server again:  5
# ********************
# 233  -  12695
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12695
# Delay before calling the server again:  6
# ********************
# 234  -  12696
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12696
# Delay before calling the server again:  10
# ********************
# 235  -  12698
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12698
# Delay before calling the server again:  8
# ********************
# 236  -  12703
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12703
# Delay before calling the server again:  9
# ********************
# 237  -  12705
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12705
# Delay before calling the server again:  7
# ********************
# 238  -  12712
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12712
# Delay before calling the server again:  8
# ********************
# 239  -  13356
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13356
# Delay before calling the server again:  10
# ********************
# 240  -  13365
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13365
# Delay before calling the server again:  8
# ********************
# 241  -  13370
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13370
# Delay before calling the server again:  7
# ********************
# 242  -  13386
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13386
# Delay before calling the server again:  9
# ********************
# 243  -  13393
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13393
# Delay before calling the server again:  5
# ********************
# 244  -  13396
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13396
# Delay before calling the server again:  9
# ********************
# 245  -  13405
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13405
# Delay before calling the server again:  9
# ********************
# 246  -  13407
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13407
# Delay before calling the server again:  6
# ********************
# 247  -  13425
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13425
# Delay before calling the server again:  8
# ********************
# 248  -  13433
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13433
# Delay before calling the server again:  7
# ********************
# 249  -  13459
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13459
# Delay before calling the server again:  8
# ********************
# 250  -  13462
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13462
# Delay before calling the server again:  8
# ********************
# 251  -  13466
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13466
# Delay before calling the server again:  5
# ********************
# 252  -  13472
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13472
# Delay before calling the server again:  7
# ********************
# 253  -  13485
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13485
# Delay before calling the server again:  10
# ********************
# 254  -  13496
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13496
# Delay before calling the server again:  8
# ********************
# 255  -  13518
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13518
# Delay before calling the server again:  8
# ********************
# 256  -  13521
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13521
# Delay before calling the server again:  6
# ********************
# 257  -  13540
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13540
# Delay before calling the server again:  6
# ********************
# 258  -  13545
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13545
# Delay before calling the server again:  8
# ********************
# 259  -  13548
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13548
# Delay before calling the server again:  6
# ********************
# 260  -  13558
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13558
# Delay before calling the server again:  9
# ********************
# 261  -  13577
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13577
# Delay before calling the server again:  10
# ********************
# 262  -  13594
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13594
# Delay before calling the server again:  9
# ********************
# 263  -  13605
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13605
# Delay before calling the server again:  5
# ********************
# 264  -  13620
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13620
# Delay before calling the server again:  7
# ********************
# 265  -  13621
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13621
# Delay before calling the server again:  5
# ********************
# 266  -  13624
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13624
# Delay before calling the server again:  10
# ********************
# 267  -  13628
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13628
# Delay before calling the server again:  8
# ********************
# 268  -  13646
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13646
# Delay before calling the server again:  10
# ********************
# 269  -  13688
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13688
# Delay before calling the server again:  8
# ********************
# 270  -  13700
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13700
# Delay before calling the server again:  7
# ********************
# 271  -  13709
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13709
# Delay before calling the server again:  7
# ********************
# 272  -  13715
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13715
# Delay before calling the server again:  10
# ********************
# 273  -  13716
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13716
# Delay before calling the server again:  6
# ********************
# 274  -  13742
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13742
# Delay before calling the server again:  9
# ********************
# 275  -  13745
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13745
# Delay before calling the server again:  10
# ********************
# 276  -  13769
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13769
# Delay before calling the server again:  9
# ********************
# 277  -  13774
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13774
# Delay before calling the server again:  7
# ********************
# 278  -  13779
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13779
# Delay before calling the server again:  9
# ********************
# 279  -  13785
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13785
# Delay before calling the server again:  5
# ********************
# 280  -  13799
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13799
# Delay before calling the server again:  8
# ********************
# 281  -  13813
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13813
# Delay before calling the server again:  9
# ********************
# 282  -  13899
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13899
# Delay before calling the server again:  10
# ********************
# 283  -  13908
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13908
# Delay before calling the server again:  9
# ********************
# 284  -  13953
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13953
# Delay before calling the server again:  7
# ********************
# 285  -  13994
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13994
# Delay before calling the server again:  7
# ********************
# 286  -  13999
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13999
# Delay before calling the server again:  6
# ********************
# 287  -  14008
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=14008
# Delay before calling the server again:  7
# ********************
# 288  -  14088
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=14088
# Delay before calling the server again:  7
# ********************
# 289  -  14316
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=14316
# Delay before calling the server again:  7
# ********************
# 290  -  14356
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=14356
# Delay before calling the server again:  5
# ********************
# 291  -  14388
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=14388
# Delay before calling the server again:  8
# ********************
# 292  -  13480
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13480
# Delay before calling the server again:  9
# ********************
# 293  -  13863
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13863
# Delay before calling the server again:  5
# ********************
# 294  -  12490
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12490
# Delay before calling the server again:  9
# ********************
# 295  -  14420
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=14420
# Delay before calling the server again:  8
# ********************
# 296  -  12586
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12586
# Delay before calling the server again:  7
# ********************
# 297  -  14120
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=14120
# Delay before calling the server again:  5
# ********************
# 298  -  12573
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12573
# Delay before calling the server again:  6
# ********************
# 299  -  14379
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=14379
# Delay before calling the server again:  8
# ********************
# 300  -  13525
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13525
# Delay before calling the server again:  6
# ********************
# 301  -  12611
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12611
# Delay before calling the server again:  5
# ********************
# 302  -  12634
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12634
# Delay before calling the server again:  10
# ********************
# 303  -  12643
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12643
# Delay before calling the server again:  10
# ********************
# 304  -  12535
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12535
# Delay before calling the server again:  6
# ********************
# 305  -  12658
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12658
# Delay before calling the server again:  9
# ********************
# 306  -  14031
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=14031
# Delay before calling the server again:  6
# ********************
# 307  -  12656
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12656
# Delay before calling the server again:  7
# ********************
# 308  -  12521
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12521
# Delay before calling the server again:  7
# ********************
# 309  -  12615
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12615
# Delay before calling the server again:  10
# ********************
# 310  -  13387
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13387
# Delay before calling the server again:  9
# ********************
# 311  -  12502
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12502
# Delay before calling the server again:  8
# ********************
# 312  -  12520
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12520
# Delay before calling the server again:  6
# ********************
# 313  -  12590
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12590
# Delay before calling the server again:  5
# ********************
# 314  -  12598
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12598
# Delay before calling the server again:  6
# ********************
# 315  -  12639
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12639
# Delay before calling the server again:  7
# ********************
# 316  -  12659
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12659
# Delay before calling the server again:  7
# ********************
# 317  -  12662
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12662
# Delay before calling the server again:  6
# ********************
# 318  -  12664
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12664
# Delay before calling the server again:  9
# ********************
# 319  -  12666
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=12666
# Delay before calling the server again:  10
# ********************
# 320  -  13652
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13652
# Delay before calling the server again:  7
# ********************
# 321  -  13781
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13781
# Delay before calling the server again:  5
# ********************
# 322  -  13962
# https://my4.raceresult.com/161079/RRPublish/data/splits?key=374250657b42ce1a7a8e1a4a3311786d&pid=13962
# Delay before calling the server again:  7
# ********************

# %%
# Convert the station list to a DataFrame
aid_station_df = pd.DataFrame(station_list, columns= ['ID', 'Aid Station', 'Exists?',
                              'formatted_gun', 
                              'formatted_chip',
                              'formatted_sector'])

aid_station_df['Year'] = year
aid_station_df['Race'] = 'SP360'

aid_station_df['PK'] = aid_station_df['Race'] +'_' + aid_station_df['Year'] +'_' + aid_station_df['ID']    

# Preview the DataFrame
print(aid_station_df.head())
# aid_station_df.to_excel(f'Data/SwissPeaks360_{year}_aid_stations.xlsx', index=False)
# Out:
#       ID Aid Station  Exists?  formatted_gun formatted_chip formatted_sector  \
# 0  14362  START 360K     True     00 days 03            NaN              NaN
# 1  14362   Fiesch IN     True   6 days 53:08   6 days 53:05     6 days 53:05
# 2  14362  Fiesch OUT     True   7 days 22:08   7 days 22:05       29 days 00
# 3  14362   Eisten IN     True  17 days 23:43  17 days 23:41    10 days 01:36
# 4  14362  Eisten OUT     True  17 days 50:47  17 days 50:45       27 days 04
#
#    Year   Race                PK
# 0  2021  SP360  SP360_2021_14362
# 1  2021  SP360  SP360_2021_14362
# 2  2021  SP360  SP360_2021_14362
# 3  2021  SP360  SP360_2021_14362
# 4  2021  SP360  SP360_2021_14362

# %%
aid_station_df['Aid Station'].unique()
# Out:
# array(['START 360K', 'Fiesch IN', 'Fiesch OUT', 'Eisten IN', 'Eisten OUT',
#        'Grimentz IN', 'Grimentz OUT', 'Grande-Dixence IN',
#        'Grande-Dixence OUT', 'Finhaut IN', 'Finhaut OUT', 'Crosets IN',
#        'Crosets OUT', 'Annonceur', 'FINISH Bouveret'], dtype=object)

# %%
aid_station_df.to_excel(f'Data/SwissPeaks360_{year}_aid_stations.xlsx', index=False)

# %%
# End the timer
end_time = time.time()

# Calculate and print execution time
execution_time = end_time - start_time
print(f"Execution time: {execution_time:.6f} seconds")
# Out:
# Execution time: 2744.359657 seconds
