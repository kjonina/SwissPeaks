# %%
import requests
import json
import html
import pandas as pd
import time
import numpy as np
import matplotlib.pyplot as plt
import unicodedata
import re
# Out:
# C:\Users\Karina\miniconda3\lib\site-packages\requests\__init__.py:109: RequestsDependencyWarning: urllib3 (2.2.2) or chardet (3.0.4)/charset_normalizer (2.0.4) doesn't match a supported version!
#   warnings.warn(

# %%
# Function to remove special characters
def normalize_name(name):
    # Normalize to remove accents and special characters
    name = unicodedata.normalize('NFD', name)
    # Encode to ASCII and ignore errors, then decode back to string
    name = name.encode('ascii', 'ignore').decode('utf-8')
    return name

# %%
# # URL of the JSON file
# url = "https://itra.run/Races/RaceResults/TOR330.Tor.des.G%C3%A9ants%C2%AE/2023/80226"

# # Send a GET request to fetch the JSON data
# response = requests.get(url)
# response

# %%
years = [ 
        '2024', # NO DNFs! AAAAAAAAAAAAAAAAAAh!
        '2023', # NO DNFs! AAAAAAAAAAAAAAAAAAh!
        '2022', 
        '2021',  # NO DNFs! AAAAAAAAAAAAAAAAAAh!
        '2020',
        '2019',
        '2018', 
#          '2017'
]

races = ['SwissPeaks360', 'SwissPeaks360_DUO']

# %% [markdown]
# #### Loading ITRA

# %%
SP_itra_df = {}
# races = ['TOR450']

for race in races:
    for year in years:
        try:

            file = f'Data/ITRA/TXT/{race}_{year}.txt'
            df = pd.read_csv(file, delimiter='\t', 
                         dtype={'Time': 'string'})    

            # renaming columns so it is easier later to compare
            df = df.rename(columns={"Runner": "Name",
                                    "Gender": "Sex",
                                    "Nationality": "ITRA_Nationality",
                                   })

            # change the name to a title case
            df['Name'] = df['Name'].str.title()
            df['Name'] = df['Name'].apply(normalize_name)
            

            # Convert 'Time' to timedelta format
            df['Performance'] = pd.to_timedelta(df['Time'], errors='coerce')
            # Calculate total seconds and create 'Performance_Seconds' column
            df['Performance_Seconds'] = df['Performance'].dt.total_seconds()


            df['Status'] = np.where(df['Performance'].isna(), 'DNF', 'Finished')
            df['Year'] = f'{year}'
            df['Race'] = f'{race}'

    #             # Drop the intermediate columns if they're no longer needed
            df = df.drop(columns=['Time', '#'])

            df['Name'] = df['Name'].str.strip()
            df['Name'] = df['Name'].str.replace(',', '')
            df['Name'] = df['Name'].str.replace('\'', '')
            df['Name'] = df['Name'].str.replace('-', '')
            df['Name'] = df['Name'].str.replace(r"\s+", " ")

    #             print(race, year, '\n', df.head())

            # Store the DataFrame in the dictionary with a key like 'TOR330_2021'
            SP_itra_df[f'{race}_{year}'] = df
            print('* ',f'{race}_{year} {df.shape}', '\n')
        except:

            if year == '2018' :
                pass
            elif year == '2019':
                pass
            else:
                print(f'issues with {race}_{year}')
                print(f'{file}')
                print('\n')
# Out:
# C:\Users\Karina\AppData\Local\Temp\ipykernel_23000\4092482852.py:40: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Name'] = df['Name'].str.replace(r"\s+", " ")
# *  SwissPeaks360_2024 (133, 9)
# C:\Users\Karina\AppData\Local\Temp\ipykernel_23000\4092482852.py:40: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Name'] = df['Name'].str.replace(r"\s+", " ")
# C:\Users\Karina\AppData\Local\Temp\ipykernel_23000\4092482852.py:40: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Name'] = df['Name'].str.replace(r"\s+", " ")
# *  SwissPeaks360_2023 (147, 9)
#
# *  SwissPeaks360_2022 (228, 9)
# C:\Users\Karina\AppData\Local\Temp\ipykernel_23000\4092482852.py:40: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Name'] = df['Name'].str.replace(r"\s+", " ")
# C:\Users\Karina\AppData\Local\Temp\ipykernel_23000\4092482852.py:40: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Name'] = df['Name'].str.replace(r"\s+", " ")
# C:\Users\Karina\AppData\Local\Temp\ipykernel_23000\4092482852.py:40: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Name'] = df['Name'].str.replace(r"\s+", " ")
# C:\Users\Karina\AppData\Local\Temp\ipykernel_23000\4092482852.py:40: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Name'] = df['Name'].str.replace(r"\s+", " ")
# *  SwissPeaks360_2021 (182, 9)
#
# *  SwissPeaks360_2020 (218, 9)
#
# *  SwissPeaks360_2019 (240, 9)
#
# *  SwissPeaks360_2018 (300, 9)
# C:\Users\Karina\AppData\Local\Temp\ipykernel_23000\4092482852.py:40: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Name'] = df['Name'].str.replace(r"\s+", " ")
# *  SwissPeaks360_DUO_2024 (18, 9)
#
# *  SwissPeaks360_DUO_2023 (14, 9)
#
# *  SwissPeaks360_DUO_2022 (30, 9)
#
# *  SwissPeaks360_DUO_2021 (14, 10)
#
# *  SwissPeaks360_DUO_2020 (18, 9)
# C:\Users\Karina\AppData\Local\Temp\ipykernel_23000\4092482852.py:40: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Name'] = df['Name'].str.replace(r"\s+", " ")
# C:\Users\Karina\AppData\Local\Temp\ipykernel_23000\4092482852.py:40: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Name'] = df['Name'].str.replace(r"\s+", " ")
# C:\Users\Karina\AppData\Local\Temp\ipykernel_23000\4092482852.py:40: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Name'] = df['Name'].str.replace(r"\s+", " ")
# C:\Users\Karina\AppData\Local\Temp\ipykernel_23000\4092482852.py:40: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Name'] = df['Name'].str.replace(r"\s+", " ")

# %%
for race in races:
    for year in years:
        try:
            SP_year = SP_itra_df[f'{race}_{year}']
            # Count the occurrences of each status
            status_counts = SP_year['Status'].value_counts()
            print(race, year, '\n', status_counts, '\n', '*'*40)
        except:
            pass
# Out:
# SwissPeaks360 2024
#  Finished    133
# Name: Status, dtype: int64
#  ****************************************
# SwissPeaks360 2023
#  Finished    147
# Name: Status, dtype: int64
#  ****************************************
# SwissPeaks360 2022
#  Finished    127
# DNF         101
# Name: Status, dtype: int64
#  ****************************************
# SwissPeaks360 2021
#  Finished    182
# Name: Status, dtype: int64
#  ****************************************
# SwissPeaks360 2020
#  Finished    142
# DNF          76
# Name: Status, dtype: int64
#  ****************************************
# SwissPeaks360 2019
#  Finished    146
# DNF          94
# Name: Status, dtype: int64
#  ****************************************
# SwissPeaks360 2018
#  Finished    193
# DNF         107
# Name: Status, dtype: int64
#  ****************************************
# SwissPeaks360_DUO 2024
#  Finished    18
# Name: Status, dtype: int64
#  ****************************************
# SwissPeaks360_DUO 2023
#  Finished    14
# Name: Status, dtype: int64
#  ****************************************
# SwissPeaks360_DUO 2022
#  Finished    16
# DNF         14
# Name: Status, dtype: int64
#  ****************************************
# SwissPeaks360_DUO 2021
#  Finished    14
# Name: Status, dtype: int64
#  ****************************************
# SwissPeaks360_DUO 2020
#  Finished    12
# DNF          6
# Name: Status, dtype: int64
#  ****************************************

# %%
SP_itra_df
# Out:
# {'SwissPeaks360_2024':                              Name  Age Sex ITRA_Nationality     Performance  \
#  0                    Collison Kim   44   M              GBR 3 days 15:09:32
#  1            Bourguignon Matthieu   45   M              FRA 4 days 02:00:06
#  2                  Barbier Adrien   35   M              FRA 4 days 04:20:57
#  3    Galve Sainz De Varanda Jorge   39   M              ESP 4 days 04:20:57
#  4                   Orradre Inigo   46   M              ESP 4 days 07:09:31
#  ..                            ...  ...  ..              ...             ...
#  128             Hopkins Elizabeth   53   F              GBR 6 days 10:24:05
#  129                 Husson Gaetan   51   M              FRA 6 days 11:20:03
#  130                      Heng Bou   55   M              FRA 6 days 11:28:13
#  131                Das Neves Tony   52   M              FRA 6 days 11:39:30
#  132               Schmitt Vincent   57   M              FRA 6 days 12:04:14
#
#       Performance_Seconds    Status  Year           Race
#  0               313772.0  Finished  2024  SwissPeaks360
#  1               352806.0  Finished  2024  SwissPeaks360
#  2               361257.0  Finished  2024  SwissPeaks360
#  3               361257.0  Finished  2024  SwissPeaks360
#  4               371371.0  Finished  2024  SwissPeaks360
#  ..                   ...       ...   ...            ...
#  128             555845.0  Finished  2024  SwissPeaks360
#  129             559203.0  Finished  2024  SwissPeaks360
#  130             559693.0  Finished  2024  SwissPeaks360
#  7             Dorne Franck   56   M              FRA 5 days 01:41:43
#  8               Roser Gael   44   M              FRA 5 days 10:01:41
#  9           Thiriet Fabien   37   M              FRA 5 days 10:01:41
#  10          Morisoli Mauro   55   M              SUI 5 days 12:05:50
#  11  Perret Morisoli Annouk   46   F              SUI 5 days 12:05:50
#  12         Berthou Vincent   54   M              FRA             NaT
#  13           Binder Hubert   52   M              FRA             NaT
#  14            Binder Marie   50   F              FRA             NaT
#  15            Braga Andrea   32   M              FRA             NaT
#  16            Krumm Tobias   43   M              GER             NaT
#  17            Warlich Anke   40   F              GER             NaT
#
#      Performance_Seconds    Status  Year               Race
#  0              401947.0  Finished  2020  SwissPeaks360_DUO
#  1              401947.0  Finished  2020  SwissPeaks360_DUO
#  2              415444.0  Finished  2020  SwissPeaks360_DUO
#  3              415444.0  Finished  2020  SwissPeaks360_DUO
#  4              420232.0  Finished  2020  SwissPeaks360_DUO
#  5              420232.0  Finished  2020  SwissPeaks360_DUO
#  6              438103.0  Finished  2020  SwissPeaks360_DUO
#  7              438103.0  Finished  2020  SwissPeaks360_DUO
#  8              468101.0  Finished  2020  SwissPeaks360_DUO
#  9              468101.0  Finished  2020  SwissPeaks360_DUO
#  10             475550.0  Finished  2020  SwissPeaks360_DUO
#  11             475550.0  Finished  2020  SwissPeaks360_DUO
#  12                  NaN       DNF  2020  SwissPeaks360_DUO
#  13                  NaN       DNF  2020  SwissPeaks360_DUO
#  14                  NaN       DNF  2020  SwissPeaks360_DUO
#  15                  NaN       DNF  2020  SwissPeaks360_DUO
#  16                  NaN       DNF  2020  SwissPeaks360_DUO
#  17                  NaN       DNF  2020  SwissPeaks360_DUO  }

# %%
# Append using pd.concat
SP_itra_df = pd.concat(SP_itra_df)
SP_itra_df = SP_itra_df.reset_index(drop = True)
SP_itra_df.isna().sum()
# Out:
# Name                      0
# Age                       0
# Sex                       7
# ITRA_Nationality         14
# Performance             398
# Performance_Seconds     398
# Status                    0
# Year                      0
# Race                      0
# Race Score             1528
# dtype: int64

# %%
SP_itra_df
# Out:
#                               Name Age Sex ITRA_Nationality     Performance  \
# 0                     Collison Kim  44   M              GBR 3 days 15:09:32
# 1             Bourguignon Matthieu  45   M              FRA 4 days 02:00:06
# 2                   Barbier Adrien  35   M              FRA 4 days 04:20:57
# 3     Galve Sainz De Varanda Jorge  39   M              ESP 4 days 04:20:57
# 4                    Orradre Inigo  46   M              ESP 4 days 07:09:31
# ...                            ...  ..  ..              ...             ...
# 1537                 Binder Hubert  52   M              FRA             NaT
# 1538                  Binder Marie  50   F              FRA             NaT
# 1539                  Braga Andrea  32   M              FRA             NaT
# 1540                  Krumm Tobias  43   M              GER             NaT
# 1541                  Warlich Anke  40   F              GER             NaT
#
#       Performance_Seconds    Status  Year               Race  Race Score
# 0                313772.0  Finished  2024      SwissPeaks360         NaN
# 1                352806.0  Finished  2024      SwissPeaks360         NaN
# 2                361257.0  Finished  2024      SwissPeaks360         NaN
# 3                361257.0  Finished  2024      SwissPeaks360         NaN
# 4                371371.0  Finished  2024      SwissPeaks360         NaN
# ...                   ...       ...   ...                ...         ...
# 1537                  NaN       DNF  2020  SwissPeaks360_DUO         NaN
# 1538                  NaN       DNF  2020  SwissPeaks360_DUO         NaN
# 1539                  NaN       DNF  2020  SwissPeaks360_DUO         NaN
# 1540                  NaN       DNF  2020  SwissPeaks360_DUO         NaN
# 1541                  NaN       DNF  2020  SwissPeaks360_DUO         NaN
#
# [1542 rows x 10 columns]

# %%
def categorize_age(age):
    if age < 40: # under40
        return 'SEN'
    elif age < 50: #40-49
        return 'V1'
    elif age < 60: #50-59
        return 'V2'
    elif age < 70: #60-69
        return 'V3'
    elif age >= 70:
        return 'V4' # Over 70
    else:
        return '-'
    
SP_itra_df['Age'] = SP_itra_df['Age'].str.replace('-', '0')
SP_itra_df['Age'] = pd.to_numeric(SP_itra_df['Age'], errors='coerce')

SP_itra_df['Age Category'] = SP_itra_df['Age'].apply(categorize_age)

# %% [markdown]
# ## EDA of ITRA

# %%
SP_itra_df[SP_itra_df['Sex'].isna()]
# Out:
#                 Name   Age  Sex ITRA_Nationality     Performance  \
# 106    Ravat Olivier   NaN  NaN              CAN 6 days 02:39:29
# 242     Grondin Eric   NaN  NaN              FRA 5 days 22:30:31
# 339     Bryant Shane  44.0  NaN              USA 5 days 12:26:00
# 363      Jones David  60.0  NaN              GBR 5 days 22:14:05
# 444    Fleith Michel  44.0  NaN              FRA             NaT
# 552   Carlier Julien   NaN  NaN              FRA 5 days 02:48:27
# 782  Milewicz Daniel   NaN  NaN              POL 4 days 17:51:24
#
#      Performance_Seconds    Status  Year           Race  Race Score  \
# 106             527969.0  Finished  2024  SwissPeaks360         NaN
# 242             513031.0  Finished  2023  SwissPeaks360         NaN
# 339             476760.0  Finished  2022  SwissPeaks360         NaN
# 363             512045.0  Finished  2022  SwissPeaks360         NaN
# 444                  NaN       DNF  2022  SwissPeaks360         NaN
# 552             442107.0  Finished  2021  SwissPeaks360         NaN
# 782             409884.0  Finished  2020  SwissPeaks360         NaN
#
#     Age Category
# 106            -
# 242            -
# 339           V1
# 363           V3
# 444           V1
# 552            -
# 782            -

# %%
SP_itra_df['Sex'] = SP_itra_df['Sex'].fillna('M')

# %%
# grabbing all finishers 
SP_itra_df['Performance'] = SP_itra_df['Performance'].astype('str')

SP_itra_df = SP_itra_df[[
    'Name', 'ITRA_Nationality', 'Sex',  'Age', 'Age Category',
    'Performance','Performance_Seconds','Status',
    'Race', 'Year'
]]
SP_itra_df
# SP_itra_df.to_excel(f'{race} Data/5. Clean Data for Data Visualisation/{race}_itra_including_DNF.xlsx' , index = False)
# Out:
# C:\Users\Karina\AppData\Local\Temp\ipykernel_23000\1550834694.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SP_itra_df['Performance'] = SP_itra_df['Performance'].astype('str')
#                               Name ITRA_Nationality Sex  Age Age Category  \
# 0                     Collison Kim              GBR   M  NaN            -
# 1             Bourguignon Matthieu              FRA   M  NaN            -
# 2                   Barbier Adrien              FRA   M  NaN            -
# 3     Galve Sainz De Varanda Jorge              ESP   M  NaN            -
# 4                    Orradre Inigo              ESP   M  NaN            -
# ...                            ...              ...  ..  ...          ...
# 1537                 Binder Hubert              FRA   M  NaN            -
# 1538                  Binder Marie              FRA   F  NaN            -
# 1539                  Braga Andrea              FRA   M  NaN            -
# 1540                  Krumm Tobias              GER   M  NaN            -
# 1541                  Warlich Anke              GER   F  NaN            -
#
#           Performance  Performance_Seconds    Status               Race  Year
# 0     3 days 15:09:32             313772.0  Finished      SwissPeaks360  2024
# 1     4 days 02:00:06             352806.0  Finished      SwissPeaks360  2024
# 2     4 days 04:20:57             361257.0  Finished      SwissPeaks360  2024
# 3     4 days 04:20:57             361257.0  Finished      SwissPeaks360  2024
# 4     4 days 07:09:31             371371.0  Finished      SwissPeaks360  2024
# ...               ...                  ...       ...                ...   ...
# 1537              NaT                  NaN       DNF  SwissPeaks360_DUO  2020
# 1538              NaT                  NaN       DNF  SwissPeaks360_DUO  2020
# 1539              NaT                  NaN       DNF  SwissPeaks360_DUO  2020
# 1540              NaT                  NaN       DNF  SwissPeaks360_DUO  2020
# 1541              NaT                  NaN       DNF  SwissPeaks360_DUO  2020
#
# [1542 rows x 10 columns]

# %%
SP_itra_df[(SP_itra_df['Year']=='2018')|
            (SP_itra_df['Year']=='2019')|
            (SP_itra_df['Year']=='2021')|
            (SP_itra_df['Year']=='2022')|
            (SP_itra_df['Year']=='2023')|
            (SP_itra_df['Year']=='2024')].groupby(['Status', 'Year'])['Status' ].count().to_frame('count').reset_index()
# Out:
#      Status  Year  count
# 0       DNF  2018    107
# 1       DNF  2019     94
# 2       DNF  2022    115
# 3  Finished  2018    193
# 4  Finished  2019    146
# 5  Finished  2021    196
# 6  Finished  2022    143
# 7  Finished  2023    161
# 8  Finished  2024    151

# %% [markdown]
# ### Extracting only Finishers

# %%
# SP_itra_df
SP_itra_no_DNF = SP_itra_df[(SP_itra_df['Status'] != 'DNF') ].reset_index(drop = True)
SP_itra_no_DNF = SP_itra_no_DNF[[
    'Name', 'ITRA_Nationality', 'Sex',  'Age', 'Age Category',
    'Performance','Performance_Seconds','Status',
    'Race', 'Year'
]]

# %%
SP_itra_no_DNF['Status'].unique()
# Out:
# array(['Finished'], dtype=object)

# %%
SP_itra_no_DNF.isna().sum()
# Out:
# Name                     0
# ITRA_Nationality        14
# Sex                      0
# Age                    824
# Age Category             0
# Performance              0
# Performance_Seconds      0
# Status                   0
# Race                     0
# Year                     0
# dtype: int64

# %%
SP_itra_no_DNF.head()
# Out:
#                            Name ITRA_Nationality Sex  Age Age Category  \
# 0                  Collison Kim              GBR   M  NaN            -
# 1          Bourguignon Matthieu              FRA   M  NaN            -
# 2                Barbier Adrien              FRA   M  NaN            -
# 3  Galve Sainz De Varanda Jorge              ESP   M  NaN            -
# 4                 Orradre Inigo              ESP   M  NaN            -
#
#        Performance  Performance_Seconds    Status           Race  Year
# 0  3 days 15:09:32             313772.0  Finished  SwissPeaks360  2024
# 1  4 days 02:00:06             352806.0  Finished  SwissPeaks360  2024
# 2  4 days 04:20:57             361257.0  Finished  SwissPeaks360  2024
# 3  4 days 04:20:57             361257.0  Finished  SwissPeaks360  2024
# 4  4 days 07:09:31             371371.0  Finished  SwissPeaks360  2024

# %%
SP_itra_no_DNF.groupby(['Status', 'Year'])['Status', 'Year'].count()
# Out:
# C:\Users\Karina\AppData\Local\Temp\ipykernel_23000\74827669.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   SP_itra_no_DNF.groupby(['Status', 'Year'])['Status', 'Year'].count()
#                Status  Year
# Status   Year
# Finished 2018     193   193
#          2019     146   146
#          2020     154   154
#          2021     196   196
#          2022     143   143
#          2023     161   161
#          2024     151   151

# %% [markdown]
# ### This data might be used later data Visualisations

# %%
# grabbing all finishers 
SP_itra_no_DNF['Performance'] = SP_itra_no_DNF['Performance'].astype('str')

SP_itra_no_DNF.to_excel(f'{ra Data/SwissPeaks_itra_no_DNF.xlsx' , index = False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [57], in <cell line: 4>()
#       1 # grabbing all finishers
#       2 SP_itra_no_DNF['Performance'] = SP_itra_no_DNF['Performance'].astype('str')
# ----> 4 SP_itra_no_DNF.to_excel(f'{race} Data/SwissPeaks_itra_no_DNF.xlsx' , index = False)
#
# File ~\miniconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\miniconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\miniconda3\lib\site-packages\pandas\core\generic.py:2374, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2361 from pandas.io.formats.excel import ExcelFormatter
#    2363 formatter = ExcelFormatter(
#    2364     df,
#    2365     na_rep=na_rep,
#    (...)
#    2372     inf_rep=inf_rep,
#    2373 )
# -> 2374 formatter.write(
#    2375     excel_writer,
#    2376     sheet_name=sheet_name,
#    2377     startrow=startrow,
#    2378     startcol=startcol,
#    2379     freeze_panes=freeze_panes,
#    2380     engine=engine,
#    2381     storage_options=storage_options,
#    2382 )
#
# File ~\miniconda3\lib\site-packages\pandas\io\formats\excel.py:944, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     940     need_save = False
#     941 else:
#     942     # error: Cannot instantiate abstract class 'ExcelWriter' with abstract
#     943     # attributes 'engine', 'save', 'supported_extensions' and 'write_cells'
# --> 944     writer = ExcelWriter(  # type: ignore[abstract]
#     945         writer, engine=engine, storage_options=storage_options
#     946     )
#     947     need_save = True
#     949 try:
#
# File ~\miniconda3\lib\site-packages\pandas\io\excel\_xlsxwriter.py:205, in XlsxWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#     202 if mode == "a":
#     203     raise ValueError("Append mode is not supported with xlsxwriter!")
# --> 205 super().__init__(
#     206     path,
#     207     engine=engine,
#     208     date_format=date_format,
#     209     datetime_format=datetime_format,
#     210     mode=mode,
#     211     storage_options=storage_options,
#     212     if_sheet_exists=if_sheet_exists,
#     213     engine_kwargs=engine_kwargs,
#     214 )
#     216 self._book = Workbook(self._handles.handle, **engine_kwargs)
#
# File ~\miniconda3\lib\site-packages\pandas\io\excel\_base.py:1313, in ExcelWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#    1309 self._handles = IOHandles(
#    1310     cast(IO[bytes], path), compression={"compression": None}
#    1311 )
#    1312 if not isinstance(path, ExcelWriter):
# -> 1313     self._handles = get_handle(
#    1314         path, mode, storage_options=storage_options, is_text=False
#    1315     )
#    1316 self._cur_sheet = None
#    1318 if date_format is None:
#
# File ~\miniconda3\lib\site-packages\pandas\io\common.py:734, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     732 # Only for write methods
#     733 if "r" not in mode and is_path:
# --> 734     check_parent_directory(str(handle))
#     736 if compression:
#     737     if compression != "zstd":
#     738         # compression libraries do not like an explicit text-mode
#
# File ~\miniconda3\lib\site-packages\pandas\io\common.py:597, in check_parent_directory(path)
#     595 parent = Path(path).parent
#     596 if not parent.is_dir():
# --> 597     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'SwissPeaks360_DUO Data'
